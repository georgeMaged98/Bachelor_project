# %% [markdown]
# # Per-Exercise Classification using fixed length signal of 2 seconds (200 rows) based on restimulus column

# %% [markdown]
# **Basic Imports and Helper Functions**

# %%
# Imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
def load_data_DB1(subject,exercise):
    data = loadmat(f'../Dataset/DB1/s{subject}/S{subject}_A1_E{exercise}.mat')
    return data

# %%
def get_start_indexes(data,movement,target):
    start_indexes=[]
    for idx,move in enumerate(data[target]):
        if move[0] == movement and data[target][idx-1][0] == 0:
            start_indexes.append(idx)
        if len(start_indexes) == 10:
            break
    return start_indexes

# %%
from sklearn.preprocessing import StandardScaler


def get_movement_df_standardized(data,movement,target):
    '''
    Returns the repetitions of a movement based on fixed length of repetition.
    if target is stimulus then each rep takes 5 seconds but if target is restimulus then each rep takes 2 seconds
    '''
    start_indexes = get_start_indexes(data,movement,target)
    df= pd.DataFrame()
    step = 500 if target == 'stimulus' else 200
    
    scaler = StandardScaler()
    
    for i in start_indexes:
        move_rep = data['emg'][i:i+step]
        scaler = StandardScaler()
        move_rep_transformed = scaler.fit_transform(move_rep).flatten()
        df = df.append(pd.Series(move_rep_transformed),ignore_index=True)
    target_movement = np.full((10,1),movement,dtype=int)
    df['target'] = target_movement
    return df

# %%
def get_movement_df(data,movement,target):
    '''
    Returns the repetitions of a movement based on fixed length of repetition.
    if target is stimulus then each rep takes 5 seconds but if target is restimulus then each rep takes 2 seconds
    '''
    start_indexes = get_start_indexes(data,movement,target)
    df= pd.DataFrame()
    step = 500 if target == 'stimulus' else 200
    for i in start_indexes:
        new_row = data['emg'][i:i+step].flatten()
        df = df.append(pd.Series(new_row),ignore_index=True)
    target_movement = np.full((10,1),movement,dtype=int)
    df['target'] = target_movement
    return df

# %% [markdown]
# ## Classification of movements for two subjects (7, 19) to compare between different machine learning models

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

models = {"LogisticRegression": LogisticRegression(max_iter=10000),
         "SVC": SVC(kernel='rbf'),
         "RandomForestClassifier": RandomForestClassifier(n_estimators=100),
         "KNN": KNeighborsClassifier(n_neighbors=5)}

# %% [markdown]
# ### Subject 7
#
# **Exercise 1**

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

sub7_ex1 = load_data_DB1(subject= 7, exercise=1)

ex1_movements = np.arange(1,13)
sub7_ex1_df = pd.DataFrame()

# Add movements to dataframe
for m in ex1_movements:

    sub7_ex1_df = sub7_ex1_df.append(get_movement_df(data=sub7_ex1, movement=m, target="restimulus"), ignore_index=True)

sub7_ex1_df
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 0    0.0024  0.3345  0.0024  0.0024  0.0024  0.0366  0.3003  0.1465  0.0269
# 1    0.0024  0.1855  0.0024  0.0049  0.0024  0.1636  0.2856  0.1270  0.0024
# 2    0.0024  0.0684  0.0049  0.0024  0.0024  0.0928  0.3833  0.1343  0.0024
# 3    0.0024  0.3198  0.0024  0.0049  0.0024  0.2026  0.5054  0.1416  0.0049
# 4    0.0073  0.1440  0.0024  0.0024  0.0024  0.1465  0.3613  0.1294  0.0024
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 115  0.0024  0.0024  0.0073  0.0024  0.0024  0.0024  0.2295  0.0293  0.0098
# 116  0.0049  0.0024  0.0024  0.0024  0.0024  0.0073  0.2100  0.0391  0.0146
# 117  0.0024  0.0024  0.0024  0.0049  0.0024  0.0635  0.2856  0.1221  0.0195
# 118  0.0024  0.0024  0.0024  0.0024  0.0024  0.0537  0.2002  0.0757  0.0391
# 119  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.1733  0.0757  0.0024
#
#           9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0    0.1660  ...  0.5249  0.0122  0.0220  0.0513  0.4932  0.5298  0.3662
# 1    0.1880  ...  0.7153  0.0024  0.0049  0.0244  0.2563  0.5713  0.2148
# 2    0.1587  ...  0.7227  0.0049  0.0073  0.0366  0.5518  0.8130  0.2197
# 3    0.2734  ...  0.8276  0.0171  0.0195  0.0806  0.7886  1.0059  0.3027
# 4    0.2490  ...  0.7080  0.0098  0.0220  0.0757  0.6177  0.9497  0.2661
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 115  0.4663  ...  0.0024  0.0024  0.0024  0.0024  0.0024  0.2075  0.0073
# 116  0.4761  ...  0.0464  0.0024  0.0024  0.0049  0.0439  0.2710  0.3491
# 117  0.4224  ...  0.2026  0.0757  0.0024  0.0024  0.0488  0.3101  0.2832
# 118  0.4272  ...  0.0024  0.0024  0.0024  0.0024  0.0073  0.2222  0.1001
# 119  0.4053  ...  0.0024  0.0024  0.0024  0.0024  0.0024  0.1367  0.0488
#
#        1998    1999  target
# 0    0.1367  0.2637       1
# 1    0.2466  0.2002       1
# 2    0.1636  0.1880       1
# 3    0.3979  0.3174       1
# 4    0.2637  0.2466       1
# ..      ...     ...     ...
# 115  0.0122  0.4761      12
# 116  0.0562  0.4663      12
# 117  0.1978  0.4517      12
# 118  0.0024  0.3857      12
# 119  0.0098  0.4126      12
#
# [120 rows x 2001 columns]

# %%
X = sub7_ex1_df.drop("target", axis=1)
y = sub7_ex1_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc.score(X_test, y_test)
# Out:
# 0.5

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

sub7_ex1 = load_data_DB1(subject= 7, exercise=1)

ex1_movements = np.arange(1,13)
sub7_ex1_df = pd.DataFrame()

# Add movements to dataframe
for m in ex1_movements:

    sub7_ex1_df = sub7_ex1_df.append(get_movement_df(data=sub7_ex1, movement=m, target="restimulus"), ignore_index=True)

sub7_ex1_df
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 0    0.0024  0.3345  0.0024  0.0024  0.0024  0.0366  0.3003  0.1465  0.0269
# 1    0.0024  0.1855  0.0024  0.0049  0.0024  0.1636  0.2856  0.1270  0.0024
# 2    0.0024  0.0684  0.0049  0.0024  0.0024  0.0928  0.3833  0.1343  0.0024
# 3    0.0024  0.3198  0.0024  0.0049  0.0024  0.2026  0.5054  0.1416  0.0049
# 4    0.0073  0.1440  0.0024  0.0024  0.0024  0.1465  0.3613  0.1294  0.0024
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 115  0.0024  0.0024  0.0073  0.0024  0.0024  0.0024  0.2295  0.0293  0.0098
# 116  0.0049  0.0024  0.0024  0.0024  0.0024  0.0073  0.2100  0.0391  0.0146
# 117  0.0024  0.0024  0.0024  0.0049  0.0024  0.0635  0.2856  0.1221  0.0195
# 118  0.0024  0.0024  0.0024  0.0024  0.0024  0.0537  0.2002  0.0757  0.0391
# 119  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.1733  0.0757  0.0024
#
#           9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0    0.1660  ...  0.5249  0.0122  0.0220  0.0513  0.4932  0.5298  0.3662
# 1    0.1880  ...  0.7153  0.0024  0.0049  0.0244  0.2563  0.5713  0.2148
# 2    0.1587  ...  0.7227  0.0049  0.0073  0.0366  0.5518  0.8130  0.2197
# 3    0.2734  ...  0.8276  0.0171  0.0195  0.0806  0.7886  1.0059  0.3027
# 4    0.2490  ...  0.7080  0.0098  0.0220  0.0757  0.6177  0.9497  0.2661
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 115  0.4663  ...  0.0024  0.0024  0.0024  0.0024  0.0024  0.2075  0.0073
# 116  0.4761  ...  0.0464  0.0024  0.0024  0.0049  0.0439  0.2710  0.3491
# 117  0.4224  ...  0.2026  0.0757  0.0024  0.0024  0.0488  0.3101  0.2832
# 118  0.4272  ...  0.0024  0.0024  0.0024  0.0024  0.0073  0.2222  0.1001
# 119  0.4053  ...  0.0024  0.0024  0.0024  0.0024  0.0024  0.1367  0.0488
#
#        1998    1999  target
# 0    0.1367  0.2637       1
# 1    0.2466  0.2002       1
# 2    0.1636  0.1880       1
# 3    0.3979  0.3174       1
# 4    0.2637  0.2466       1
# ..      ...     ...     ...
# 115  0.0122  0.4761      12
# 116  0.0562  0.4663      12
# 117  0.1978  0.4517      12
# 118  0.0024  0.3857      12
# 119  0.0098  0.4126      12
#
# [120 rows x 2001 columns]

# %%
X = sub7_ex1_df.drop("target", axis=1)
y = sub7_ex1_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

rfc.score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
X = sub7_ex1_df.drop("target", axis=1)
y = sub7_ex1_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

sub7_ex1_accs = {}

for label, model in models.items():
    model.fit(X_train, y_train)
    sub7_ex1_accs[label] = round(model.score(X_test, y_test) * 100, 2)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(sub7_ex1_accs.keys(), sub7_ex1_accs.values())
ax.set_title("Comparing Accuracies of Different Models classifying Exercise 1 for subject 7")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, sub7_ex1_accs.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Exercise 2**

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

sub7_ex2 = load_data_DB1(subject= 7, exercise=2)

ex2_movements = np.arange(1,18)
sub7_ex2_df = pd.DataFrame()

# Add movements to dataframe
for m in ex2_movements:
    sub7_ex2_df = sub7_ex2_df.append(get_movement_df(data=sub7_ex2, movement=m, target="restimulus"))

sub7_ex2_df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0024  0.0024  0.0024  0.0024  0.0024  0.1416  0.4297  0.1636  0.0024
# 1  0.0024  0.0024  0.0024  0.0024  0.0024  0.0586  0.4272  0.1294  0.0024
# 2  0.0049  0.0024  0.0024  0.0024  0.0024  0.0879  0.5737  0.1416  0.0024
# 3  0.0024  0.0024  0.0024  0.0024  0.0049  0.0195  0.1538  0.1099  0.0024
# 4  0.0171  0.0024  0.0024  0.0024  0.0024  0.0562  0.4199  0.1343  0.0122
#
#         9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0  0.1685  ...  0.6104  0.0171  0.0049  0.0220  0.1978  1.1890  0.5884
# 1  0.1807  ...  0.6177  0.0098  0.0244  0.0269  0.1904  1.2866  0.5811
# 2  0.1831  ...  0.4590  0.0073  0.0244  0.0293  0.1465  0.8765  0.5835
# 3  0.1440  ...  0.6104  0.0146  0.0220  0.0293  0.1660  1.2427  0.5444
# 4  0.1880  ...  0.6592  0.0342  0.0220  0.0391  0.2246  1.2549  0.6396
#
#      1998    1999  target
# 0  0.1099  0.5298       1
# 1  0.1465  0.4126       1
# 2  0.1343  0.3101       1
# 3  0.1758  0.3735       1
# 4  0.0854  0.3711       1
#
# [5 rows x 2001 columns]

# %%
X = sub7_ex2_df.drop("target", axis=1)
y = sub7_ex2_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

sub7_ex2_accs = {}

for label, model in models.items():
    model.fit(X_train, y_train)
    sub7_ex2_accs[label] = round(model.score(X_test, y_test) * 100, 2)

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 16})

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(sub7_ex2_accs.keys(), sub7_ex2_accs.values())
ax.set_title("Comparing Accuracies of Different Models classifying Exercise 2 for subject 7")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, sub7_ex2_accs.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Exercise 3**

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

sub7_ex3 = load_data_DB1(subject= 7, exercise=3)

ex3_movements = np.arange(1,24)
sub7_ex3_df = pd.DataFrame()

# Add movements to dataframe
for m in ex3_movements:
    sub7_ex3_df = sub7_ex3_df.append(get_movement_df(data=sub7_ex3, movement=m, target="restimulus"))

sub7_ex3_df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0024  0.0024  0.0195  0.0171  0.0293  0.2832  0.3101  0.0903  0.0024
# 1  0.0024  0.0024  0.0024  0.0024  0.0024  0.1660  0.3809  0.0513  0.0024
# 2  0.0024  0.0024  0.0024  0.0024  0.0024  0.1221  0.2441  0.4199  0.0024
# 3  0.0024  0.0024  0.0049  0.0073  0.0049  0.0952  0.0610  0.2124  0.0024
# 4  0.0049  0.0024  0.0024  0.0024  0.0317  0.3735  0.1563  0.1245  0.0024
#
#         9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0  0.2295  ...  0.2319  0.0244  0.0757  0.3638  2.0068  0.3345  0.5591
# 1  0.2295  ...  0.3271  0.0879  0.0562  0.3174  2.0557  0.4907  0.5249
# 2  0.2515  ...  0.0488  0.0171  0.1001  0.2490  1.2402  0.4199  0.5469
# 3  0.2393  ...  0.0708  0.0073  0.0195  0.2197  1.3208  0.2271  0.4175
# 4  0.1636  ...  0.0342  0.0049  0.0122  0.1611  1.0278  0.3760  0.4956
#
#      1998    1999  target
# 0  0.3394  0.1538       1
# 1  0.3418  0.2246       1
# 2  0.0439  0.2539       1
# 3  0.1147  0.1733       1
# 4  0.0342  0.1855       1
#
# [5 rows x 2001 columns]

# %%
X = sub7_ex3_df.drop("target", axis=1)
y = sub7_ex3_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

sub7_ex3_accs = {}

for label, model in models.items():
    model.fit(X_train, y_train)
    sub7_ex3_accs[label] = round(model.score(X_test, y_test) * 100, 2)

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 16})

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))


ax.bar(sub7_ex3_accs.keys(), sub7_ex3_accs.values())
ax.set_title("Comparing Accuracies of Different Models classifying Exercise 3 for subject 7")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, sub7_ex3_accs.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# ### Subject 19
#
# **Exercise 1**

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

sub19_ex1 = load_data_DB1(subject= 19, exercise=1)

ex1_movements = np.arange(1,13)
sub19_ex1_df = pd.DataFrame()

# Add movements to dataframe
for m in ex1_movements:
    sub19_ex1_df = sub19_ex1_df.append(get_movement_df(data=sub19_ex1, movement=m, target="restimulus"))

sub19_ex1_df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0977  0.0024  0.0024  0.0024  0.0049  0.0024  0.0073  0.3564  0.0024
# 1  0.0342  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.2856  0.0024
# 2  0.0073  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.2197  0.0024
# 3  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.1270  0.0024
# 4  0.6763  0.1099  0.0244  0.0024  0.0024  0.0024  0.0024  0.0342  0.0024
#
#         9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0  0.1318  ...  0.0024  0.0293  0.0024  0.0024  0.0024  0.0024  0.2881
# 1  0.0854  ...  0.0024  0.2344  0.0757  0.0049  0.0024  0.0073  0.2539
# 2  0.0220  ...  0.0024  0.2002  0.0659  0.0049  0.0024  0.0024  0.3247
# 3  0.0122  ...  0.0854  0.0024  0.0024  0.0024  0.0024  0.0024  0.0757
# 4  0.0024  ...  0.0488  0.0928  0.0098  0.0024  0.0024  0.0024  0.2881
#
#      1998    1999  target
# 0  0.0171  0.0195       1
# 1  0.0806  0.0269       1
# 2  0.0830  0.0171       1
# 3  0.0024  0.0024       1
# 4  0.0171  0.0220       1
#
# [5 rows x 2001 columns]

# %%
X = sub19_ex1_df.drop("target", axis=1)
y = sub19_ex1_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

sub19_ex1_accs = {}

for label, model in models.items():
    model.fit(X_train, y_train)
    sub19_ex1_accs[label] = round(model.score(X_test, y_test) * 100, 2)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(sub19_ex1_accs.keys(), sub19_ex1_accs.values())
ax.set_title("Comparing Accuracies of Different Models classifying Exercise 1 for subject 19")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, sub19_ex1_accs.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Exercise 2**

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

sub19_ex2 = load_data_DB1(subject= 19, exercise=2)

ex2_movements = np.arange(1,18)
sub19_ex2_df = pd.DataFrame()

# Add movements to dataframe
for m in ex2_movements:
    sub19_ex2_df = sub19_ex2_df.append(get_movement_df(data=sub19_ex2, movement=m, target="restimulus"))

sub19_ex2_df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  1.0376  0.1172  0.3271  0.2173  0.0220  0.0024  0.2588  0.4492  0.3271
# 1  0.6592  0.2710  0.0024  0.0024  0.0024  0.0024  0.0024  0.2051  0.0024
# 2  0.4370  0.4175  0.0024  0.0024  0.0024  0.0024  0.0195  0.4175  0.0024
# 3  0.5859  0.3101  0.0049  0.0024  0.0024  0.0024  0.0122  0.4639  0.0024
# 4  0.4004  0.3076  0.0024  0.0024  0.0024  0.0024  0.0146  0.3296  0.0024
#
#         9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0  2.0483  ...  0.6201  0.1880  0.0098  0.0024  0.0024  0.0293  0.2563
# 1  0.0098  ...  0.2661  0.2637  0.0830  0.0024  0.0024  0.1025  0.3369
# 2  0.0635  ...  0.5029  0.4297  0.0439  0.0024  0.0024  0.1782  0.5981
# 3  0.0659  ...  0.6934  0.2637  0.0244  0.0024  0.0024  0.0708  0.2686
# 4  0.0415  ...  0.3394  0.4541  0.1904  0.0024  0.0024  0.0439  0.2759
#
#      1998    1999  target
# 0  0.0415  0.2856       1
# 1  0.0635  0.3662       1
# 2  0.1050  0.5933       1
# 3  0.0537  0.7520       1
# 4  0.2783  0.9302       1
#
# [5 rows x 2001 columns]

# %%
X = sub19_ex2_df.drop("target", axis=1)
y = sub19_ex2_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

sub19_ex2_accs = {}

for label, model in models.items():
    model.fit(X_train, y_train)
    sub19_ex2_accs[label] = round(model.score(X_test, y_test) * 100, 2)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(sub19_ex2_accs.keys(), sub19_ex2_accs.values())
ax.set_title("Comparing Accuracies of Different Models classifying Exercise 2 for subject 19")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, sub19_ex2_accs.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 1, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Exercise 3**

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)

sub19_ex3 = load_data_DB1(subject=19, exercise=3)

ex3_movements = np.arange(1,24)
sub19_ex3_df = pd.DataFrame()

# Add movements to dataframe
for m in ex3_movements:
    sub19_ex3_df = sub19_ex3_df.append(get_movement_df(data=sub19_ex3, movement=m, target="restimulus"))

sub19_ex3_df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0757  0.0024  0.0024  0.0024  0.0024  0.0024  0.1538  0.0220  0.0024
# 1  0.1440  0.0366  0.0024  0.0024  0.0024  0.0024  0.0684  0.0122  0.0024
# 2  0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391  0.0366  0.0024
# 3  0.0073  0.0024  0.0024  0.0024  0.0024  0.0024  0.0757  0.0488  0.0024
# 4  0.0562  0.0024  0.0024  0.0024  0.0024  0.0024  0.0464  0.0635  0.0024
#
#         9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0  0.0049  ...  0.9351  0.0830  0.1270  0.0171  0.0488  1.3818  0.5396
# 1  0.0122  ...  0.5176  0.0024  0.0024  0.0024  0.0171  0.5615  0.1929
# 2  0.0049  ...  0.4980  0.0195  0.0024  0.0024  0.0635  0.7495  0.3003
# 3  0.0391  ...  0.4346  0.0293  0.0098  0.0024  0.0415  0.7080  0.3638
# 4  0.0220  ...  0.5542  0.1099  0.0635  0.0171  0.0757  1.0718  0.4102
#
#      1998    1999  target
# 0  0.0684  0.1929       1
# 1  0.0024  0.0513       1
# 2  0.0024  0.1221       1
# 3  0.0073  0.0806       1
# 4  0.0244  0.1514       1
#
# [5 rows x 2001 columns]

# %%
X = sub19_ex3_df.drop("target", axis=1)
y = sub19_ex3_df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

sub19_ex3_accs = {}

for label, model in models.items():
    model.fit(X_train, y_train)
    sub19_ex3_accs[label] = round(model.score(X_test, y_test) * 100, 2)

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(sub19_ex3_accs.keys(), sub19_ex3_accs.values())
ax.set_title("Comparing Accuracies of Different Models classifying Exercise 3 for subject 19")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, sub19_ex3_accs.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Models Used**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

models = {"LogisticRegression": LogisticRegression(max_iter=10000, n_jobs=-1),
         "SVC": SVC(kernel='rbf'),
         "RandomForestClassifier": RandomForestClassifier(n_estimators=100, n_jobs=-1),
         "KNN": KNeighborsClassifier(n_neighbors=5, n_jobs=-1)}

# %% [markdown]
# # 0. Showing data representation

# %%
sub_data = load_data_DB1(subject=13, exercise=2)

sub_data_df = get_movement_df(data=sub_data, movement=3, target='restimulus')
sub_data_df
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0073  0.0024  0.0024  0.0024  0.0024  0.0244  0.0830  0.1245  0.0049
# 1  0.0024  0.0024  0.0098  0.0024  0.0024  0.0317  0.0342  0.0928  0.0049
# 2  0.0049  0.0024  0.0122  0.0024  0.0024  0.0635  0.0781  0.1074  0.0073
# 3  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391  0.0708  0.1221  0.0073
# 4  0.0024  0.0024  0.0073  0.0024  0.0024  0.0781  0.1123  0.1196  0.0146
# 5  0.0024  0.0244  0.0122  0.0024  0.0024  0.0024  0.0732  0.1270  0.0024
# 6  0.0024  0.0098  0.0122  0.0024  0.0024  0.0366  0.1099  0.1172  0.0073
# 7  0.0024  0.0122  0.0098  0.0024  0.0024  0.0024  0.0977  0.1318  0.0024
# 8  0.0024  0.0024  0.0146  0.0024  0.0024  0.0146  0.1465  0.1636  0.0244
# 9  0.0024  0.0317  0.0220  0.0024  0.0024  0.0024  0.1001  0.1538  0.0122
#
#         9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0  0.4688  ...  1.2549  0.2881  0.0024  0.0391  0.2075  2.2266  0.7007
# 1  0.3491  ...  0.8008  0.3027  0.0024  0.0024  0.1147  1.7114  0.8325
# 2  0.2515  ...  0.1294  0.0146  0.0024  0.0024  0.0854  0.4346  0.1929
# 3  0.2832  ...  0.8252  0.1587  0.0024  0.0024  0.1758  1.9531  0.7715
# 4  0.2979  ...  0.7983  0.2319  0.0024  0.0098  0.1465  1.0889  0.5493
# 5  0.2686  ...  1.0962  0.2686  0.0073  0.0269  0.2612  2.1191  0.9204
# 6  0.2808  ...  0.7910  0.2319  0.0024  0.0146  0.2148  1.4819  0.5518
# 7  0.2783  ...  1.0083  0.1660  0.0024  0.0049  0.1001  1.0986  0.8276
# 8  0.2905  ...  0.0024  0.0049  0.0024  0.0073  0.1831  0.2905  0.1733
# 9  0.2515  ...  0.7202  0.1953  0.0024  0.0122  0.1660  1.6943  0.6885
#
#      1998    1999  target
# 0  0.4492  0.5005       3
# 1  0.2686  0.2637       3
# 2  0.0635  0.2783       3
# 3  0.2417  0.2539       3
# 4  0.2466  0.2563       3
# 5  0.4077  0.2734       3
# 6  0.2295  0.2734       3
# 7  0.1733  0.2393       3
# 8  0.0024  0.2563       3
# 9  0.1855  0.2783       3
#
# [10 rows x 2001 columns]

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,6))
plt.rcParams.update({'font.size': 16})

ax.plot(np.arange(0,2000), sub_data_df.iloc[9].drop("target"))
ax.set_title("Subject 13, Exercise 2, Movement 3, Repetition 10")
ax.set_xlabel("Movement Repetition Length")
ax.set_xticks(np.arange(0,2000,200))
ax.set_ylabel("Signal Amplitude");

# %% [markdown]
# # 1. Classification of movements per exercise per subjects

# %% [markdown]
# **Exercise 1**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

np.random.seed(42)

# test_acc_ex1_rf = []
# test_acc_ex1_log = []

test_accuracy_models = {}
# Initialize lists for each model .. Each list should contain 27 values(number of subjects)

for label, model in models.items():
    test_accuracy_models[label] = []
    
ex1_movements = np.arange(1,13)

# Iterate over 27 subjects of DB1 and trying to classify exercise 1 
for sub in np.arange(1,28):
    
    # Load the data 
    data = load_data_DB1(subject=sub, exercise=1)
    
    # Iterate over all movements and add them into a df
    df = pd.DataFrame()
    for m in ex1_movements:
        df = df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    # Getting X & y
    X = df.drop("target", axis=1)
    y = df["target"]
        
    # Splitting the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    
    #Fitting the model
    for label, model in models.items():

        model.fit(X_train, y_train)
        score = round(model.score(X_test, y_test) * 100, 3)
        test_accuracy_models[label].append(score)
        print(f"Test Accuracy for subject {sub} in exercise 1 using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------")

for label, model in models.items():
    print(f"Average Test Accuracy for all subjects in exercise 1 using {label} {np.mean(test_accuracy_models[label])}")
# Out:
# Test Accuracy for subject 1 in exercise 1 using LogisticRegression is 83.333
# Test Accuracy for subject 1 in exercise 1 using SVC is 75.0
# Test Accuracy for subject 1 in exercise 1 using RandomForestClassifier is 83.333
# Test Accuracy for subject 1 in exercise 1 using KNN is 66.667
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 2 in exercise 1 using LogisticRegression is 91.667
# Test Accuracy for subject 2 in exercise 1 using SVC is 91.667
# Test Accuracy for subject 2 in exercise 1 using RandomForestClassifier is 100.0
# Test Accuracy for subject 2 in exercise 1 using KNN is 87.5
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 3 in exercise 1 using LogisticRegression is 91.667
# Test Accuracy for subject 3 in exercise 1 using SVC is 79.167
# Test Accuracy for subject 3 in exercise 1 using RandomForestClassifier is 83.333
# Test Accuracy for subject 3 in exercise 1 using KNN is 62.5
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 4 in exercise 1 using LogisticRegression is 91.667
# Test Accuracy for subject 4 in exercise 1 using SVC is 79.167
# Test Accuracy for subject 4 in exercise 1 using RandomForestClassifier is 91.667
# Test Accuracy for subject 4 in exercise 1 using KNN is 79.167
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 5 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 5 in exercise 1 using SVC is 83.333
# Test Accuracy for subject 5 in exercise 1 using RandomForestClassifier is 83.333
# Test Accuracy for subject 5 in exercise 1 using KNN is 87.5
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 6 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 6 in exercise 1 using SVC is 83.333
# Test Accuracy for subject 6 in exercise 1 using RandomForestClassifier is 95.833
# Test Accuracy for subject 6 in exercise 1 using KNN is 87.5
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 7 in exercise 1 using LogisticRegression is 91.667
# Test Accuracy for subject 7 in exercise 1 using SVC is 83.333
# Test Accuracy for subject 7 in exercise 1 using RandomForestClassifier is 83.333
# Test Accuracy for subject 7 in exercise 1 using KNN is 83.333
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 8 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 8 in exercise 1 using SVC is 87.5
# Test Accuracy for subject 8 in exercise 1 using RandomForestClassifier is 91.667
# Test Accuracy for subject 8 in exercise 1 using KNN is 87.5
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 9 in exercise 1 using LogisticRegression is 83.333
# Test Accuracy for subject 9 in exercise 1 using SVC is 50.0
# Test Accuracy for subject 9 in exercise 1 using RandomForestClassifier is 87.5
# Test Accuracy for subject 9 in exercise 1 using KNN is 66.667
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 10 in exercise 1 using LogisticRegression is 83.333
# Test Accuracy for subject 10 in exercise 1 using SVC is 83.333
# Test Accuracy for subject 10 in exercise 1 using RandomForestClassifier is 83.333
# Test Accuracy for subject 10 in exercise 1 using KNN is 83.333
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 11 in exercise 1 using LogisticRegression is 95.833
# Test Accuracy for subject 11 in exercise 1 using SVC is 91.667
# Test Accuracy for subject 11 in exercise 1 using RandomForestClassifier is 95.833
# Test Accuracy for subject 11 in exercise 1 using KNN is 91.667
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 12 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 12 in exercise 1 using SVC is 79.167
# Test Accuracy for subject 12 in exercise 1 using RandomForestClassifier is 87.5
# Test Accuracy for subject 12 in exercise 1 using KNN is 79.167
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 13 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 13 in exercise 1 using SVC is 79.167
# Test Accuracy for subject 13 in exercise 1 using RandomForestClassifier is 91.667
# Test Accuracy for subject 13 in exercise 1 using KNN is 79.167
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 14 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 14 in exercise 1 using SVC is 83.333
# Test Accuracy for subject 14 in exercise 1 using RandomForestClassifier is 87.5
# Test Accuracy for subject 14 in exercise 1 using KNN is 83.333
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 15 in exercise 1 using LogisticRegression is 91.667
# Test Accuracy for subject 15 in exercise 1 using SVC is 79.167
# Test Accuracy for subject 15 in exercise 1 using RandomForestClassifier is 91.667
# Test Accuracy for subject 15 in exercise 1 using KNN is 79.167
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 16 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 16 in exercise 1 using SVC is 66.667
# Test Accuracy for subject 16 in exercise 1 using RandomForestClassifier is 79.167
# Test Accuracy for subject 16 in exercise 1 using KNN is 75.0
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 17 in exercise 1 using LogisticRegression is 100.0
# Test Accuracy for subject 17 in exercise 1 using SVC is 87.5
# Test Accuracy for subject 17 in exercise 1 using RandomForestClassifier is 91.667
# Test Accuracy for subject 17 in exercise 1 using KNN is 87.5
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 18 in exercise 1 using LogisticRegression is 95.833
# Test Accuracy for subject 18 in exercise 1 using SVC is 79.167
# Test Accuracy for subject 18 in exercise 1 using RandomForestClassifier is 95.833
# Test Accuracy for subject 18 in exercise 1 using KNN is 79.167
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 19 in exercise 1 using LogisticRegression is 91.667
# Test Accuracy for subject 19 in exercise 1 using SVC is 83.333
# Test Accuracy for subject 19 in exercise 1 using RandomForestClassifier is 83.333
# Test Accuracy for subject 19 in exercise 1 using KNN is 79.167
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 20 in exercise 1 using LogisticRegression is 95.833
# Test Accuracy for subject 20 in exercise 1 using SVC is 100.0
# Test Accuracy for subject 20 in exercise 1 using RandomForestClassifier is 91.667
# Test Accuracy for subject 20 in exercise 1 using KNN is 95.833
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 21 in exercise 1 using LogisticRegression is 100.0
# Test Accuracy for subject 21 in exercise 1 using SVC is 100.0
# Test Accuracy for subject 21 in exercise 1 using RandomForestClassifier is 95.833
# Test Accuracy for subject 21 in exercise 1 using KNN is 100.0
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 22 in exercise 1 using LogisticRegression is 79.167
# Test Accuracy for subject 22 in exercise 1 using SVC is 79.167
# Test Accuracy for subject 22 in exercise 1 using RandomForestClassifier is 79.167
# Test Accuracy for subject 22 in exercise 1 using KNN is 79.167
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 23 in exercise 1 using LogisticRegression is 79.167
# Test Accuracy for subject 23 in exercise 1 using SVC is 70.833
# Test Accuracy for subject 23 in exercise 1 using RandomForestClassifier is 91.667
# Test Accuracy for subject 23 in exercise 1 using KNN is 75.0
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 24 in exercise 1 using LogisticRegression is 87.5
# Test Accuracy for subject 24 in exercise 1 using SVC is 75.0
# Test Accuracy for subject 24 in exercise 1 using RandomForestClassifier is 79.167
# Test Accuracy for subject 24 in exercise 1 using KNN is 75.0
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 25 in exercise 1 using LogisticRegression is 95.833
# Test Accuracy for subject 25 in exercise 1 using SVC is 91.667
# Test Accuracy for subject 25 in exercise 1 using RandomForestClassifier is 95.833
# Test Accuracy for subject 25 in exercise 1 using KNN is 100.0
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 26 in exercise 1 using LogisticRegression is 100.0
# Test Accuracy for subject 26 in exercise 1 using SVC is 91.667
# Test Accuracy for subject 26 in exercise 1 using RandomForestClassifier is 100.0
# Test Accuracy for subject 26 in exercise 1 using KNN is 95.833
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 27 in exercise 1 using LogisticRegression is 79.167
# Test Accuracy for subject 27 in exercise 1 using SVC is 75.0
# Test Accuracy for subject 27 in exercise 1 using RandomForestClassifier is 79.167
# Test Accuracy for subject 27 in exercise 1 using KNN is 83.333
# -----------------------------------------------------------------------------------
# Average Test Accuracy for all subjects in exercise 1 using LogisticRegression 89.66051851851853
# Average Test Accuracy for all subjects in exercise 1 using SVC 81.79018518518518
# Average Test Accuracy for all subjects in exercise 1 using RandomForestClassifier 88.88888888888889
# Average Test Accuracy for all subjects in exercise 1 using KNN 82.56177777777778

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,8))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_accuracy_models[label])

ax.set_title("Test Scores for 27 subjects for Exercise 1 using raw signal using different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.legend(['Logistic Regression','Support Vector Classifier', 'Random Forest', 'K-nearest neigbors' ]);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

mean_accuracies_ex1 = {}

for label, model in models.items():
    mean_accuracies_ex1[label] = np.mean(test_accuracy_models[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_ex1.keys(), mean_accuracies_ex1.values())
ax.set_title("Mean Accuracies of Different Models classifying Exercise 1 for alll subjects")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_ex1.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Exercise 2**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

np.random.seed(42)

test_accuracy_models_ex2 = {}
# Initialize lists for each model .. Each list should contain 27 values(number of subjects)

for label, model in models.items():
    test_accuracy_models_ex2[label] = []
    
ex2_movements = np.arange(1,18)

# Iterate over 27 subjects of DB1 and trying to classify exercise 1 
for sub in np.arange(1,28):
    
    # Load the data 
    data = load_data_DB1(subject=sub, exercise=2)
    
    # Iterate over all movements and add them into a df
    df = pd.DataFrame()
    for m in ex2_movements:
        df = df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    # Getting X & y
    X = df.drop("target", axis=1)
    y = df["target"]
        
    # Splitting the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    
    #Fitting the model
    for label, model in models.items():

        model.fit(X_train, y_train)
        score = round(model.score(X_test, y_test) * 100, 3)
        test_accuracy_models_ex2[label].append(score)
        print(f"Test Accuracy for subject {sub} in exercise 2 using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------")

for label, model in models.items():
    print(f"Average Test Accuracy for all subjects in exercise 2 using {label} {np.mean(test_accuracy_models_ex2[label])}")
# Out:
# Test Accuracy for subject 1 in exercise 2 using LogisticRegression is 82.353
# Test Accuracy for subject 1 in exercise 2 using SVC is 76.471
# Test Accuracy for subject 1 in exercise 2 using RandomForestClassifier is 82.353
# Test Accuracy for subject 1 in exercise 2 using KNN is 79.412
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 2 in exercise 2 using LogisticRegression is 91.176
# Test Accuracy for subject 2 in exercise 2 using SVC is 88.235
# Test Accuracy for subject 2 in exercise 2 using RandomForestClassifier is 91.176
# Test Accuracy for subject 2 in exercise 2 using KNN is 82.353
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 3 in exercise 2 using LogisticRegression is 91.176
# Test Accuracy for subject 3 in exercise 2 using SVC is 79.412
# Test Accuracy for subject 3 in exercise 2 using RandomForestClassifier is 79.412
# Test Accuracy for subject 3 in exercise 2 using KNN is 82.353
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 4 in exercise 2 using LogisticRegression is 88.235
# Test Accuracy for subject 4 in exercise 2 using SVC is 64.706
# Test Accuracy for subject 4 in exercise 2 using RandomForestClassifier is 88.235
# Test Accuracy for subject 4 in exercise 2 using KNN is 70.588
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 5 in exercise 2 using LogisticRegression is 64.706
# Test Accuracy for subject 5 in exercise 2 using SVC is 58.824
# Test Accuracy for subject 5 in exercise 2 using RandomForestClassifier is 82.353
# Test Accuracy for subject 5 in exercise 2 using KNN is 58.824
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 6 in exercise 2 using LogisticRegression is 82.353
# Test Accuracy for subject 6 in exercise 2 using SVC is 79.412
# Test Accuracy for subject 6 in exercise 2 using RandomForestClassifier is 82.353
# Test Accuracy for subject 6 in exercise 2 using KNN is 70.588
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 7 in exercise 2 using LogisticRegression is 88.235
# Test Accuracy for subject 7 in exercise 2 using SVC is 76.471
# Test Accuracy for subject 7 in exercise 2 using RandomForestClassifier is 91.176
# Test Accuracy for subject 7 in exercise 2 using KNN is 82.353
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 8 in exercise 2 using LogisticRegression is 100.0
# Test Accuracy for subject 8 in exercise 2 using SVC is 97.059
# Test Accuracy for subject 8 in exercise 2 using RandomForestClassifier is 100.0
# Test Accuracy for subject 8 in exercise 2 using KNN is 94.118
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 9 in exercise 2 using LogisticRegression is 85.294
# Test Accuracy for subject 9 in exercise 2 using SVC is 79.412
# Test Accuracy for subject 9 in exercise 2 using RandomForestClassifier is 91.176
# Test Accuracy for subject 9 in exercise 2 using KNN is 70.588
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 10 in exercise 2 using LogisticRegression is 82.353
# Test Accuracy for subject 10 in exercise 2 using SVC is 85.294
# Test Accuracy for subject 10 in exercise 2 using RandomForestClassifier is 85.294
# Test Accuracy for subject 10 in exercise 2 using KNN is 88.235
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 11 in exercise 2 using LogisticRegression is 82.353
# Test Accuracy for subject 11 in exercise 2 using SVC is 85.294
# Test Accuracy for subject 11 in exercise 2 using RandomForestClassifier is 85.294
# Test Accuracy for subject 11 in exercise 2 using KNN is 82.353
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 12 in exercise 2 using LogisticRegression is 91.176
# Test Accuracy for subject 12 in exercise 2 using SVC is 88.235
# Test Accuracy for subject 12 in exercise 2 using RandomForestClassifier is 91.176
# Test Accuracy for subject 12 in exercise 2 using KNN is 85.294
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 13 in exercise 2 using LogisticRegression is 82.353
# Test Accuracy for subject 13 in exercise 2 using SVC is 76.471
# Test Accuracy for subject 13 in exercise 2 using RandomForestClassifier is 82.353
# Test Accuracy for subject 13 in exercise 2 using KNN is 73.529
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 14 in exercise 2 using LogisticRegression is 88.235
# Test Accuracy for subject 14 in exercise 2 using SVC is 94.118
# Test Accuracy for subject 14 in exercise 2 using RandomForestClassifier is 88.235
# Test Accuracy for subject 14 in exercise 2 using KNN is 85.294
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 15 in exercise 2 using LogisticRegression is 88.235
# Test Accuracy for subject 15 in exercise 2 using SVC is 76.471
# Test Accuracy for subject 15 in exercise 2 using RandomForestClassifier is 73.529
# Test Accuracy for subject 15 in exercise 2 using KNN is 73.529
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 16 in exercise 2 using LogisticRegression is 85.294
# Test Accuracy for subject 16 in exercise 2 using SVC is 76.471
# Test Accuracy for subject 16 in exercise 2 using RandomForestClassifier is 73.529
# Test Accuracy for subject 16 in exercise 2 using KNN is 79.412
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 17 in exercise 2 using LogisticRegression is 100.0
# Test Accuracy for subject 17 in exercise 2 using SVC is 94.118
# Test Accuracy for subject 17 in exercise 2 using RandomForestClassifier is 100.0
# Test Accuracy for subject 17 in exercise 2 using KNN is 88.235
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 18 in exercise 2 using LogisticRegression is 88.235
# Test Accuracy for subject 18 in exercise 2 using SVC is 82.353
# Test Accuracy for subject 18 in exercise 2 using RandomForestClassifier is 97.059
# Test Accuracy for subject 18 in exercise 2 using KNN is 76.471
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 19 in exercise 2 using LogisticRegression is 94.118
# Test Accuracy for subject 19 in exercise 2 using SVC is 88.235
# Test Accuracy for subject 19 in exercise 2 using RandomForestClassifier is 97.059
# Test Accuracy for subject 19 in exercise 2 using KNN is 88.235
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 20 in exercise 2 using LogisticRegression is 97.059
# Test Accuracy for subject 20 in exercise 2 using SVC is 88.235
# Test Accuracy for subject 20 in exercise 2 using RandomForestClassifier is 97.059
# Test Accuracy for subject 20 in exercise 2 using KNN is 88.235
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 21 in exercise 2 using LogisticRegression is 100.0
# Test Accuracy for subject 21 in exercise 2 using SVC is 100.0
# Test Accuracy for subject 21 in exercise 2 using RandomForestClassifier is 100.0
# Test Accuracy for subject 21 in exercise 2 using KNN is 97.059
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 22 in exercise 2 using LogisticRegression is 100.0
# Test Accuracy for subject 22 in exercise 2 using SVC is 97.059
# Test Accuracy for subject 22 in exercise 2 using RandomForestClassifier is 94.118
# Test Accuracy for subject 22 in exercise 2 using KNN is 94.118
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 23 in exercise 2 using LogisticRegression is 91.176
# Test Accuracy for subject 23 in exercise 2 using SVC is 73.529
# Test Accuracy for subject 23 in exercise 2 using RandomForestClassifier is 88.235
# Test Accuracy for subject 23 in exercise 2 using KNN is 67.647
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 24 in exercise 2 using LogisticRegression is 82.353
# Test Accuracy for subject 24 in exercise 2 using SVC is 73.529
# Test Accuracy for subject 24 in exercise 2 using RandomForestClassifier is 85.294
# Test Accuracy for subject 24 in exercise 2 using KNN is 64.706
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 25 in exercise 2 using LogisticRegression is 94.118
# Test Accuracy for subject 25 in exercise 2 using SVC is 91.176
# Test Accuracy for subject 25 in exercise 2 using RandomForestClassifier is 97.059
# Test Accuracy for subject 25 in exercise 2 using KNN is 85.294
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 26 in exercise 2 using LogisticRegression is 79.412
# Test Accuracy for subject 26 in exercise 2 using SVC is 82.353
# Test Accuracy for subject 26 in exercise 2 using RandomForestClassifier is 88.235
# Test Accuracy for subject 26 in exercise 2 using KNN is 79.412
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 27 in exercise 2 using LogisticRegression is 88.235
# Test Accuracy for subject 27 in exercise 2 using SVC is 82.353
# Test Accuracy for subject 27 in exercise 2 using RandomForestClassifier is 85.294
# Test Accuracy for subject 27 in exercise 2 using KNN is 82.353
# -----------------------------------------------------------------------------------
# Average Test Accuracy for all subjects in exercise 2 using LogisticRegression 88.45307407407407
# Average Test Accuracy for all subjects in exercise 2 using SVC 82.78874074074075
# Average Test Accuracy for all subjects in exercise 2 using RandomForestClassifier 88.77985185185186
# Average Test Accuracy for all subjects in exercise 2 using KNN 80.39214814814815

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,8))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_accuracy_models_ex2[label])

ax.set_title("Test Scores for 27 subjects for Exercise 2 using raw signal using different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.legend(['Logistic Regression','Support Vector Classifier', 'Random Forest', 'K-nearest neigbors' ]);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

mean_accuracies_ex2 = {}

for label, model in models.items():
    mean_accuracies_ex2[label] = np.mean(test_accuracy_models_ex2[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_ex2.keys(), mean_accuracies_ex2.values())
ax.set_title("Mean Accuracies of Different Models classifying Exercise 2 for all subjects")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_ex2.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Exercise 3**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

np.random.seed(42)

test_accuracy_models_ex3 = {}

# Initialize lists for each model .. Each list should contain 27 values(number of subjects)
for label, model in models.items():
    test_accuracy_models_ex3[label] = []
    
ex3_movements = np.arange(1,24)

# Iterate over 27 subjects of DB1 and trying to classify exercise 3 
for sub in np.arange(1,28):
    
    # Load the data 
    data = load_data_DB1(subject=sub, exercise=3)
    
    # Iterate over all movements and add them into a df
    df = pd.DataFrame()
    for m in ex3_movements:
        df = df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    # Getting X & y
    X = df.drop("target", axis=1)
    y = df["target"]
        
    # Splitting the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    
    #Fitting the model
    for label, model in models.items():
        model.fit(X_train, y_train)
        score = model.score(X_test, y_test) * 100
        test_accuracy_models_ex3[label].append(round(score, 3))
        print(f"Test Accuracy for subject {sub} in exercise 3 using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------")

for label, model in models.items():
    print(f"Average Test Accuracy for all subjects in exercise 3 using {label} {np.mean(test_accuracy_models_ex3[label])}")
# Out:
# Test Accuracy for subject 1 in exercise 3 using LogisticRegression is 89.13043478260869
# Test Accuracy for subject 1 in exercise 3 using SVC is 78.26086956521739
# Test Accuracy for subject 1 in exercise 3 using RandomForestClassifier is 89.13043478260869
# Test Accuracy for subject 1 in exercise 3 using KNN is 82.6086956521739
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 2 in exercise 3 using LogisticRegression is 82.6086956521739
# Test Accuracy for subject 2 in exercise 3 using SVC is 71.73913043478261
# Test Accuracy for subject 2 in exercise 3 using RandomForestClassifier is 78.26086956521739
# Test Accuracy for subject 2 in exercise 3 using KNN is 71.73913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 3 in exercise 3 using LogisticRegression is 69.56521739130434
# Test Accuracy for subject 3 in exercise 3 using SVC is 67.3913043478261
# Test Accuracy for subject 3 in exercise 3 using RandomForestClassifier is 67.3913043478261
# Test Accuracy for subject 3 in exercise 3 using KNN is 71.73913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 4 in exercise 3 using LogisticRegression is 73.91304347826086
# Test Accuracy for subject 4 in exercise 3 using SVC is 52.17391304347826
# Test Accuracy for subject 4 in exercise 3 using RandomForestClassifier is 67.3913043478261
# Test Accuracy for subject 4 in exercise 3 using KNN is 47.82608695652174
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 5 in exercise 3 using LogisticRegression is 69.56521739130434
# Test Accuracy for subject 5 in exercise 3 using SVC is 56.52173913043478
# Test Accuracy for subject 5 in exercise 3 using RandomForestClassifier is 76.08695652173914
# Test Accuracy for subject 5 in exercise 3 using KNN is 71.73913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 6 in exercise 3 using LogisticRegression is 78.26086956521739
# Test Accuracy for subject 6 in exercise 3 using SVC is 73.91304347826086
# Test Accuracy for subject 6 in exercise 3 using RandomForestClassifier is 86.95652173913044
# Test Accuracy for subject 6 in exercise 3 using KNN is 76.08695652173914
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 7 in exercise 3 using LogisticRegression is 84.78260869565217
# Test Accuracy for subject 7 in exercise 3 using SVC is 82.6086956521739
# Test Accuracy for subject 7 in exercise 3 using RandomForestClassifier is 86.95652173913044
# Test Accuracy for subject 7 in exercise 3 using KNN is 78.26086956521739
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 8 in exercise 3 using LogisticRegression is 82.6086956521739
# Test Accuracy for subject 8 in exercise 3 using SVC is 63.04347826086957
# Test Accuracy for subject 8 in exercise 3 using RandomForestClassifier is 82.6086956521739
# Test Accuracy for subject 8 in exercise 3 using KNN is 71.73913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 9 in exercise 3 using LogisticRegression is 84.78260869565217
# Test Accuracy for subject 9 in exercise 3 using SVC is 69.56521739130434
# Test Accuracy for subject 9 in exercise 3 using RandomForestClassifier is 84.78260869565217
# Test Accuracy for subject 9 in exercise 3 using KNN is 67.3913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 10 in exercise 3 using LogisticRegression is 80.43478260869566
# Test Accuracy for subject 10 in exercise 3 using SVC is 60.86956521739131
# Test Accuracy for subject 10 in exercise 3 using RandomForestClassifier is 80.43478260869566
# Test Accuracy for subject 10 in exercise 3 using KNN is 67.3913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 11 in exercise 3 using LogisticRegression is 82.6086956521739
# Test Accuracy for subject 11 in exercise 3 using SVC is 71.73913043478261
# Test Accuracy for subject 11 in exercise 3 using RandomForestClassifier is 82.6086956521739
# Test Accuracy for subject 11 in exercise 3 using KNN is 67.3913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 12 in exercise 3 using LogisticRegression is 84.78260869565217
# Test Accuracy for subject 12 in exercise 3 using SVC is 80.43478260869566
# Test Accuracy for subject 12 in exercise 3 using RandomForestClassifier is 84.78260869565217
# Test Accuracy for subject 12 in exercise 3 using KNN is 76.08695652173914
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 13 in exercise 3 using LogisticRegression is 63.04347826086957
# Test Accuracy for subject 13 in exercise 3 using SVC is 56.52173913043478
# Test Accuracy for subject 13 in exercise 3 using RandomForestClassifier is 80.43478260869566
# Test Accuracy for subject 13 in exercise 3 using KNN is 54.347826086956516
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 14 in exercise 3 using LogisticRegression is 73.91304347826086
# Test Accuracy for subject 14 in exercise 3 using SVC is 71.73913043478261
# Test Accuracy for subject 14 in exercise 3 using RandomForestClassifier is 78.26086956521739
# Test Accuracy for subject 14 in exercise 3 using KNN is 69.56521739130434
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 15 in exercise 3 using LogisticRegression is 82.6086956521739
# Test Accuracy for subject 15 in exercise 3 using SVC is 69.56521739130434
# Test Accuracy for subject 15 in exercise 3 using RandomForestClassifier is 73.91304347826086
# Test Accuracy for subject 15 in exercise 3 using KNN is 71.73913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 16 in exercise 3 using LogisticRegression is 76.08695652173914
# Test Accuracy for subject 16 in exercise 3 using SVC is 67.3913043478261
# Test Accuracy for subject 16 in exercise 3 using RandomForestClassifier is 76.08695652173914
# Test Accuracy for subject 16 in exercise 3 using KNN is 56.52173913043478
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 17 in exercise 3 using LogisticRegression is 78.26086956521739
# Test Accuracy for subject 17 in exercise 3 using SVC is 73.91304347826086
# Test Accuracy for subject 17 in exercise 3 using RandomForestClassifier is 86.95652173913044
# Test Accuracy for subject 17 in exercise 3 using KNN is 60.86956521739131
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 18 in exercise 3 using LogisticRegression is 65.21739130434783
# Test Accuracy for subject 18 in exercise 3 using SVC is 65.21739130434783
# Test Accuracy for subject 18 in exercise 3 using RandomForestClassifier is 76.08695652173914
# Test Accuracy for subject 18 in exercise 3 using KNN is 65.21739130434783
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 19 in exercise 3 using LogisticRegression is 80.43478260869566
# Test Accuracy for subject 19 in exercise 3 using SVC is 71.73913043478261
# Test Accuracy for subject 19 in exercise 3 using RandomForestClassifier is 82.6086956521739
# Test Accuracy for subject 19 in exercise 3 using KNN is 71.73913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 20 in exercise 3 using LogisticRegression is 89.13043478260869
# Test Accuracy for subject 20 in exercise 3 using SVC is 67.3913043478261
# Test Accuracy for subject 20 in exercise 3 using RandomForestClassifier is 78.26086956521739
# Test Accuracy for subject 20 in exercise 3 using KNN is 69.56521739130434
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 21 in exercise 3 using LogisticRegression is 95.65217391304348
# Test Accuracy for subject 21 in exercise 3 using SVC is 93.47826086956522
# Test Accuracy for subject 21 in exercise 3 using RandomForestClassifier is 95.65217391304348
# Test Accuracy for subject 21 in exercise 3 using KNN is 93.47826086956522
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 22 in exercise 3 using LogisticRegression is 91.30434782608695
# Test Accuracy for subject 22 in exercise 3 using SVC is 86.95652173913044
# Test Accuracy for subject 22 in exercise 3 using RandomForestClassifier is 91.30434782608695
# Test Accuracy for subject 22 in exercise 3 using KNN is 86.95652173913044
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 23 in exercise 3 using LogisticRegression is 69.56521739130434
# Test Accuracy for subject 23 in exercise 3 using SVC is 73.91304347826086
# Test Accuracy for subject 23 in exercise 3 using RandomForestClassifier is 78.26086956521739
# Test Accuracy for subject 23 in exercise 3 using KNN is 65.21739130434783
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 24 in exercise 3 using LogisticRegression is 78.26086956521739
# Test Accuracy for subject 24 in exercise 3 using SVC is 73.91304347826086
# Test Accuracy for subject 24 in exercise 3 using RandomForestClassifier is 73.91304347826086
# Test Accuracy for subject 24 in exercise 3 using KNN is 69.56521739130434
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 25 in exercise 3 using LogisticRegression is 89.13043478260869
# Test Accuracy for subject 25 in exercise 3 using SVC is 76.08695652173914
# Test Accuracy for subject 25 in exercise 3 using RandomForestClassifier is 80.43478260869566
# Test Accuracy for subject 25 in exercise 3 using KNN is 80.43478260869566
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 26 in exercise 3 using LogisticRegression is 91.30434782608695
# Test Accuracy for subject 26 in exercise 3 using SVC is 71.73913043478261
# Test Accuracy for subject 26 in exercise 3 using RandomForestClassifier is 84.78260869565217
# Test Accuracy for subject 26 in exercise 3 using KNN is 71.73913043478261
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 27 in exercise 3 using LogisticRegression is 73.91304347826086
# Test Accuracy for subject 27 in exercise 3 using SVC is 67.3913043478261
# Test Accuracy for subject 27 in exercise 3 using RandomForestClassifier is 80.43478260869566
# Test Accuracy for subject 27 in exercise 3 using KNN is 60.86956521739131
# -----------------------------------------------------------------------------------
# Average Test Accuracy for all subjects in exercise 3 using LogisticRegression 80.03218518518518
# Average Test Accuracy for all subjects in exercise 3 using SVC 70.93392592592592
# Average Test Accuracy for all subjects in exercise 3 using RandomForestClassifier 80.91799999999999
# Average Test Accuracy for all subjects in exercise 3 using KNN 70.2898148148148

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,8))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_accuracy_models_ex3[label])

ax.set_title("Test Scores for 27 subjects for Exercise 3 using raw signal using different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.legend(['Logistic Regression','Support Vector Classifier', 'Random Forest', 'K-nearest neigbors' ]);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

mean_accuracies_ex3 = {}

for label, model in models.items():
    mean_accuracies_ex3[label] = np.mean(test_accuracy_models_ex3[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_ex3.keys(), mean_accuracies_ex3.values())
ax.set_title("Mean Accuracies of Different Models classifying Exercise 3 for all subjects")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_ex3.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# **Comparing average accuracies for all subjects in the different exercises**

# %%
ex1_mean = np.mean(test_acc_subjects_ex1)
ex2_mean = np.mean(test_acc_subjects_ex2)
ex3_mean = np.mean(test_acc_subjects_ex3)

# %%
# Plot Bar graph to compare accuracy across exercises
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,8))
plt.rcParams.update({'font.size': 22})

exercises = ["Exercise 1", "Exercise 2", "Exercise 3"]
mean_accs = [ex1_mean, ex2_mean, ex3_mean]
ax.bar(exercises, mean_accs)
ax.set_title("Comparing Mean Test Accuracies across subjects for different Exercises")
ax.set_xlabel("Exercises")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accs):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# # 2. Classification for movements per exercise using leave-one-out approach

# %% [markdown]
# ### Classification of exercise 1 movements PER SUBJECT using leave one out method and computing the average for all subjects using RandomForest Classifier
#
# **Data is based on the concatenation of 200 rows of a movement repetition based on restimulus column**
# Adding the data for all subjects except 1 to be training data and test the model on a subject it hasn't seen before.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

models = {"LogisticRegression": LogisticRegression(max_iter=10000, n_jobs=-1),
         "RandomForestClassifier": RandomForestClassifier(n_estimators=100, n_jobs=-1)}

# %%
ex1_movements = list(range(1,13))

df = pd.DataFrame()
# Load the data for all subjects except 1 to do leave-one out classification
for s in list(range(1,28)):
    data = load_data_DB1(subject=s, exercise=1)
    # Iterate over all movements and add them into a df
    for m in ex1_movements:
        df = df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
df
# Out:
#            0       1       2       3       4       5       6       7       8  \
# 0     0.0171  0.0073  0.0024  0.0024  0.0024  0.0024  0.0757  0.0317  0.0024
# 1     0.0488  0.0073  0.0024  0.0024  0.0024  0.0024  0.0171  0.0488  0.0024
# 2     0.0073  0.0073  0.0024  0.0024  0.0024  0.0024  0.0269  0.0391  0.0024
# 3     0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0659  0.0342  0.0024
# 4     0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0098  0.0244  0.0049
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 3235  0.2075  0.0513  0.0049  0.0024  0.0049  0.0024  0.0049  0.2368  0.0024
# 3236  0.0537  0.0024  0.0049  0.0024  0.0049  0.0049  0.0049  0.1953  0.0049
# 3237  0.0391  0.0146  0.0073  0.0024  0.0024  0.0024  0.0049  0.1514  0.0049
# 3238  0.2246  0.0024  0.0049  0.0049  0.0049  0.0024  0.0049  0.3418  0.0024
# 3239  0.2271  0.0195  0.0317  0.0098  0.0049  0.0024  0.0049  0.2466  0.0122
#
#            9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0     0.0146  ...  0.0024  0.0195  0.0024  0.0024  0.0024  0.0146  0.0488
# 1     0.0049  ...  0.0269  0.0024  0.0049  0.0024  0.0024  0.0806  0.0659
# 2     0.0049  ...  0.2197  0.0562  0.0024  0.0024  0.0024  0.1318  0.0439
# 3     0.0098  ...  0.3931  0.2759  0.0171  0.0024  0.0024  0.3101  0.0952
# 4     0.0024  ...  0.1685  0.0024  0.0122  0.0024  0.0024  0.1196  0.0537
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 3235  0.0146  ...  0.3662  0.3564  0.0073  0.0049  0.0024  0.0024  0.3711
# 3236  0.0391  ...  0.0024  0.0146  0.0146  0.0049  0.0024  0.0049  0.5273
# 3237  0.0879  ...  0.0439  0.4736  0.0488  0.0024  0.0024  0.0049  0.3906
# 3238  0.0708  ...  0.0879  0.2368  0.0049  0.0049  0.0049  0.0171  0.3320
# 3239  0.0562  ...  0.0488  0.2808  0.0073  0.0049  0.0024  0.0317  0.3687
#
#         1998    1999  target
# 0     0.0073  0.0024       1
# 1     0.0024  0.0024       1
# 2     0.2441  0.0122       1
# 3     0.5103  0.1880       1
# 4     0.0513  0.0024       1
# ...      ...     ...     ...
# 3235  0.1196  0.1196      12
# 3236  0.0488  0.0928      12
# 3237  0.2881  0.1245      12
# 3238  0.1367  0.0806      12
# 3239  0.1050  0.0757      12
#
# [3240 rows x 2001 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA

# training_acc_subjects = []
# test_acc_leave_one_ex1 = []

test_acc_leave_one_ex1 = {}
# Initialize lists for each model .. Each list should contain 27 values(number of subjects)

for label, model in models.items():
    test_acc_leave_one_ex1[label] = []
    
    
# Iterate over 27 subjects of Database 1 and trying to classify exercise 1 
for sub in list(range(1,28)):
    
    start_idx_rows = (sub - 1) * 120
    end_idx_rows = start_idx_rows + 120
    training_data = df.drop(np.arange(start_idx_rows,end_idx_rows), axis=0)
    test_data = df[start_idx_rows:end_idx_rows]
    
    # Prepare X & y for the all-but-one subject and fit the model
    X_train = training_data.drop("target", axis=1)
    y_train = training_data["target"]

    # prepare X_test and y_test
    X_test = test_data.drop("target", axis=1)
    y_test = test_data["target"]
    
    for label, model in models.items():
        model.fit(X_train, y_train)
        score = model.score(X_test, y_test) * 100
        test_acc_leave_one_ex1[label].append(round(score, 3))
        print(f"Test Accuracy leaving subject {sub} out in exercise 1 using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------") 


for label, model in models.items():
    print(f"Average Test Accuracy leaving each subject out once using {label} is {np.mean(test_acc_leave_one_ex1[label])}")
# Out:
# Test Accuracy leaving subject 1 out in exercise 1 using LogisticRegression is 32.5
# Test Accuracy leaving subject 1 out in exercise 1 using RandomForestClassifier is 26.666666666666668
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 2 out in exercise 1 using LogisticRegression is 18.333333333333332
# Test Accuracy leaving subject 2 out in exercise 1 using RandomForestClassifier is 13.333333333333334
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 3 out in exercise 1 using LogisticRegression is 36.666666666666664
# Test Accuracy leaving subject 3 out in exercise 1 using RandomForestClassifier is 45.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 4 out in exercise 1 using LogisticRegression is 26.666666666666668
# Test Accuracy leaving subject 4 out in exercise 1 using RandomForestClassifier is 32.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 5 out in exercise 1 using LogisticRegression is 34.166666666666664
# Test Accuracy leaving subject 5 out in exercise 1 using RandomForestClassifier is 43.333333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 6 out in exercise 1 using LogisticRegression is 24.166666666666668
# Test Accuracy leaving subject 6 out in exercise 1 using RandomForestClassifier is 25.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 7 out in exercise 1 using LogisticRegression is 15.0
# Test Accuracy leaving subject 7 out in exercise 1 using RandomForestClassifier is 27.500000000000004
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 8 out in exercise 1 using LogisticRegression is 44.166666666666664
# Test Accuracy leaving subject 8 out in exercise 1 using RandomForestClassifier is 39.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 9 out in exercise 1 using LogisticRegression is 37.5
# Test Accuracy leaving subject 9 out in exercise 1 using RandomForestClassifier is 17.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 10 out in exercise 1 using LogisticRegression is 33.33333333333333
# Test Accuracy leaving subject 10 out in exercise 1 using RandomForestClassifier is 41.66666666666667
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 11 out in exercise 1 using LogisticRegression is 39.166666666666664
# Test Accuracy leaving subject 11 out in exercise 1 using RandomForestClassifier is 25.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 12 out in exercise 1 using LogisticRegression is 29.166666666666668
# Test Accuracy leaving subject 12 out in exercise 1 using RandomForestClassifier is 40.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 13 out in exercise 1 using LogisticRegression is 32.5
# Test Accuracy leaving subject 13 out in exercise 1 using RandomForestClassifier is 20.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 14 out in exercise 1 using LogisticRegression is 30.0
# Test Accuracy leaving subject 14 out in exercise 1 using RandomForestClassifier is 35.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 15 out in exercise 1 using LogisticRegression is 46.666666666666664
# Test Accuracy leaving subject 15 out in exercise 1 using RandomForestClassifier is 34.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 16 out in exercise 1 using LogisticRegression is 30.0
# Test Accuracy leaving subject 16 out in exercise 1 using RandomForestClassifier is 32.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 17 out in exercise 1 using LogisticRegression is 46.666666666666664
# Test Accuracy leaving subject 17 out in exercise 1 using RandomForestClassifier is 55.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 18 out in exercise 1 using LogisticRegression is 35.0
# Test Accuracy leaving subject 18 out in exercise 1 using RandomForestClassifier is 38.333333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 19 out in exercise 1 using LogisticRegression is 25.833333333333336
# Test Accuracy leaving subject 19 out in exercise 1 using RandomForestClassifier is 30.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 20 out in exercise 1 using LogisticRegression is 27.500000000000004
# Test Accuracy leaving subject 20 out in exercise 1 using RandomForestClassifier is 30.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 21 out in exercise 1 using LogisticRegression is 48.333333333333336
# Test Accuracy leaving subject 21 out in exercise 1 using RandomForestClassifier is 49.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 22 out in exercise 1 using LogisticRegression is 26.666666666666668
# Test Accuracy leaving subject 22 out in exercise 1 using RandomForestClassifier is 30.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 23 out in exercise 1 using LogisticRegression is 40.0
# Test Accuracy leaving subject 23 out in exercise 1 using RandomForestClassifier is 43.333333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 24 out in exercise 1 using LogisticRegression is 23.333333333333332
# Test Accuracy leaving subject 24 out in exercise 1 using RandomForestClassifier is 31.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 25 out in exercise 1 using LogisticRegression is 51.66666666666667
# Test Accuracy leaving subject 25 out in exercise 1 using RandomForestClassifier is 55.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 26 out in exercise 1 using LogisticRegression is 35.0
# Test Accuracy leaving subject 26 out in exercise 1 using RandomForestClassifier is 52.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 27 out in exercise 1 using LogisticRegression is 21.666666666666668
# Test Accuracy leaving subject 27 out in exercise 1 using RandomForestClassifier is 28.333333333333332
# -----------------------------------------------------------------------------------
# Average Test Accuracy leaving each subject out once using LogisticRegression is 33.02477777777778
# Average Test Accuracy leaving each subject out once using RandomForestClassifier is 34.99996296296296

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,6))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_acc_leave_one_ex1[label])

ax.set_title("Test Scores leaving each subject out once for Exercise 1 using raw signal and different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0,100)
ax.legend(['Logistic Regression', 'Random Forest']);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

mean_accuracies_leave_one_ex1 = {}

for label, model in models.items():
    mean_accuracies_leave_one_ex1[label] = np.mean(test_acc_leave_one_ex1[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_leave_one_ex1.keys(), mean_accuracies_leave_one_ex1.values())
ax.set_title("Mean Accuracies of Different Models classifying Exercise 1 using leave-one-out approach")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_leave_one_ex1.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# ### Classification of exercise 2 movements PER SUBJECT using leave one out method and computing the average for all subjects using RandomForest Classifier
#
# **Data is based on the concatenation of 200 rows of a movement repetition based on restimulus column**
# Adding the data for all subjects except 1 to be training data and test the model on a subject it hasn't seen before.

# %%
ex2_movements = list(range(1,18))

df = pd.DataFrame()

for s in list(range(1,28)):
    data = load_data_DB1(subject=s, exercise=2)
    # Iterate over all movements and add them into a df
    for m in ex2_movements:
        df = df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0488  0.0098  0.0024  0.0024  0.0049  0.0024  0.4077  0.1660  0.0024
# 1  0.1294  0.0220  0.0024  0.0024  0.0024  0.0024  0.3149  0.1294  0.0049
# 2  0.0513  0.0049  0.0024  0.0024  0.0024  0.0024  0.3467  0.1416  0.0024
# 3  0.0195  0.0244  0.0024  0.0024  0.0024  0.0024  0.0635  0.0806  0.0024
# 4  0.0244  0.0024  0.0024  0.0024  0.0024  0.0024  0.1587  0.0757  0.0024
#
#         9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0  0.0659  ...  2.1631  1.0840  0.4980  0.2295  0.1172  0.5640  2.9077
# 1  0.0977  ...  1.3452  0.5273  0.1660  0.0757  0.0293  0.2954  3.0469
# 2  0.0391  ...  0.3516  0.1050  0.0195  0.0024  0.0024  0.0757  0.7007
# 3  0.0122  ...  0.3540  0.1025  0.0195  0.0024  0.0146  0.1538  0.5933
# 4  0.0024  ...  0.0757  0.0854  0.0024  0.0024  0.0024  0.0342  0.4907
#
#      1998    1999  target
# 0  1.0693  0.8081       1
# 1  0.8691  0.4443       1
# 2  0.1318  0.0293       1
# 3  0.1074  0.0757       1
# 4  0.0195  0.0049       1
#
# [5 rows x 2001 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA

# training_acc_subjects = []
# test_acc_leave_one_ex2 = []

test_acc_leave_one_ex2 = {}
# Initialize lists for each model .. Each list should contain 27 values(number of subjects)

for label, model in models.items():
    test_acc_leave_one_ex2[label] = []
    
    
# Iterate over 27 subjects of Database 1 and trying to classify exercise 2
for sub in list(range(1,28)):
    
    start_idx_rows = (sub - 1) * 120
    end_idx_rows = start_idx_rows + 120
    training_data = df.drop(np.arange(start_idx_rows,end_idx_rows), axis=0)
    test_data = df[start_idx_rows:end_idx_rows]
    
    # Prepare X & y for the all-but-one subject and fit the model
    X_train = training_data.drop("target", axis=1)
    y_train = training_data["target"]

    # prepare X_test and y_test
    X_test = test_data.drop("target", axis=1)
    y_test = test_data["target"]
    
    for label, model in models.items():
        model.fit(X_train, y_train)
        score = model.score(X_test, y_test) * 100
        test_acc_leave_one_ex2[label].append(round(score, 3))
        print(f"Test Accuracy leaving subject {sub} out in exercise 2 using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------") 


for label, model in models.items():
    print(f"Average Test Accuracy for Exercise 2 leaving each subject out once using {label} is {np.mean(test_acc_leave_one_ex2[label])}")
# Out:
# Test Accuracy leaving subject 1 out in exercise 2 using LogisticRegression is 25.0
# Test Accuracy leaving subject 1 out in exercise 2 using RandomForestClassifier is 37.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 2 out in exercise 2 using LogisticRegression is 27.500000000000004
# Test Accuracy leaving subject 2 out in exercise 2 using RandomForestClassifier is 29.166666666666668
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 3 out in exercise 2 using LogisticRegression is 8.333333333333332
# Test Accuracy leaving subject 3 out in exercise 2 using RandomForestClassifier is 16.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 4 out in exercise 2 using LogisticRegression is 37.5
# Test Accuracy leaving subject 4 out in exercise 2 using RandomForestClassifier is 47.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 5 out in exercise 2 using LogisticRegression is 26.666666666666668
# Test Accuracy leaving subject 5 out in exercise 2 using RandomForestClassifier is 20.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 6 out in exercise 2 using LogisticRegression is 35.833333333333336
# Test Accuracy leaving subject 6 out in exercise 2 using RandomForestClassifier is 30.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 7 out in exercise 2 using LogisticRegression is 33.33333333333333
# Test Accuracy leaving subject 7 out in exercise 2 using RandomForestClassifier is 34.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 8 out in exercise 2 using LogisticRegression is 40.833333333333336
# Test Accuracy leaving subject 8 out in exercise 2 using RandomForestClassifier is 50.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 9 out in exercise 2 using LogisticRegression is 32.5
# Test Accuracy leaving subject 9 out in exercise 2 using RandomForestClassifier is 39.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 10 out in exercise 2 using LogisticRegression is 19.166666666666668
# Test Accuracy leaving subject 10 out in exercise 2 using RandomForestClassifier is 25.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 11 out in exercise 2 using LogisticRegression is 54.166666666666664
# Test Accuracy leaving subject 11 out in exercise 2 using RandomForestClassifier is 65.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 12 out in exercise 2 using LogisticRegression is 35.833333333333336
# Test Accuracy leaving subject 12 out in exercise 2 using RandomForestClassifier is 40.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 13 out in exercise 2 using LogisticRegression is 40.0
# Test Accuracy leaving subject 13 out in exercise 2 using RandomForestClassifier is 36.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 14 out in exercise 2 using LogisticRegression is 48.333333333333336
# Test Accuracy leaving subject 14 out in exercise 2 using RandomForestClassifier is 54.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 15 out in exercise 2 using LogisticRegression is 32.5
# Test Accuracy leaving subject 15 out in exercise 2 using RandomForestClassifier is 28.333333333333332
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 16 out in exercise 2 using LogisticRegression is 45.83333333333333
# Test Accuracy leaving subject 16 out in exercise 2 using RandomForestClassifier is 39.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 17 out in exercise 2 using LogisticRegression is 62.5
# Test Accuracy leaving subject 17 out in exercise 2 using RandomForestClassifier is 63.33333333333333
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 18 out in exercise 2 using LogisticRegression is 20.0
# Test Accuracy leaving subject 18 out in exercise 2 using RandomForestClassifier is 15.833333333333332
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 19 out in exercise 2 using LogisticRegression is 39.166666666666664
# Test Accuracy leaving subject 19 out in exercise 2 using RandomForestClassifier is 47.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 20 out in exercise 2 using LogisticRegression is 56.666666666666664
# Test Accuracy leaving subject 20 out in exercise 2 using RandomForestClassifier is 57.49999999999999
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 21 out in exercise 2 using LogisticRegression is 28.333333333333332
# Test Accuracy leaving subject 21 out in exercise 2 using RandomForestClassifier is 25.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 22 out in exercise 2 using LogisticRegression is 49.166666666666664
# Test Accuracy leaving subject 22 out in exercise 2 using RandomForestClassifier is 46.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 23 out in exercise 2 using LogisticRegression is 55.00000000000001
# Test Accuracy leaving subject 23 out in exercise 2 using RandomForestClassifier is 59.166666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 24 out in exercise 2 using LogisticRegression is 56.666666666666664
# Test Accuracy leaving subject 24 out in exercise 2 using RandomForestClassifier is 61.66666666666667
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 25 out in exercise 2 using LogisticRegression is 36.666666666666664
# Test Accuracy leaving subject 25 out in exercise 2 using RandomForestClassifier is 46.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 26 out in exercise 2 using LogisticRegression is 44.166666666666664
# Test Accuracy leaving subject 26 out in exercise 2 using RandomForestClassifier is 50.83333333333333
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 27 out in exercise 2 using LogisticRegression is 45.0
# Test Accuracy leaving subject 27 out in exercise 2 using RandomForestClassifier is 60.83333333333333
# -----------------------------------------------------------------------------------
# Average Test Accuracy for Exercise 2 leaving each subject out once using LogisticRegression is 38.39507407407408
# Average Test Accuracy for Exercise 2 leaving each subject out once using RandomForestClassifier is 41.851888888888894

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,6))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_acc_leave_one_ex2[label])

ax.set_title("Test Scores leaving each subject out once for Exercise 2 using raw signal and different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0,100)
ax.legend(['Logistic Regression', 'Random Forest']);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

mean_accuracies_leave_one_ex2 = {}

for label, model in models.items():
    mean_accuracies_leave_one_ex2[label] = np.mean(test_acc_leave_one_ex2[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_leave_one_ex2.keys(), mean_accuracies_leave_one_ex2.values())
ax.set_title("Mean Accuracies of Different Models classifying Exercise 2 using leave-one-out approach")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_leave_one_ex2.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# ### Classification of exercise 3 movements PER SUBJECT using leave one out method and computing the average for all subjects using RandomForest Classifier
#
# **Data is based on the concatenation of 200 rows of a movement repetition based on restimulus column**
# Adding the data for all subjects except 1 to be training data and test the model on a subject it hasn't seen before.

# %%
ex3_movements = list(range(1,24))

df = pd.DataFrame()

for s in list(range(1,28)):
    data = load_data_DB1(subject=s, exercise=3)
    # Iterate over all movements and add them into a df
    for m in ex3_movements:
        df = df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
df
# Out:
#            0       1       2       3       4       5       6       7       8  \
# 0     0.0122  0.0024  0.0122  0.0024  0.0073  0.0024  0.0122  0.0659  0.0024
# 1     0.0049  0.0024  0.0024  0.0024  0.0098  0.0024  0.0293  0.0903  0.0024
# 2     0.0098  0.0024  0.0024  0.0024  0.0098  0.0024  0.0024  0.1538  0.0024
# 3     0.0220  0.0024  0.0024  0.0024  0.0098  0.0049  0.0098  0.1050  0.0024
# 4     0.0146  0.0024  0.0024  0.0024  0.0049  0.0049  0.0317  0.1465  0.0024
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 6205  0.6982  0.1538  0.4712  0.0195  0.0049  0.0024  0.0342  0.4712  1.1426
# 6206  0.2686  0.0537  0.1929  0.0049  0.0049  0.0024  0.0073  0.2075  0.1147
# 6207  0.3491  0.1392  0.3320  0.0049  0.0024  0.0024  0.0122  0.2515  0.0732
# 6208  0.0757  0.0049  0.1172  0.0049  0.0049  0.0024  0.0049  0.0977  0.0659
# 6209  1.4136  0.7642  0.6616  0.0781  0.0439  0.0024  0.1099  0.5322  0.4736
#
#            9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0     0.0439  ...  0.1685  0.9302  0.0073  0.0098  0.0513  0.5688  0.4321
# 1     0.0391  ...  0.0464  0.6567  0.2197  0.0024  0.0024  0.1245  0.1074
# 2     0.0513  ...  0.1538  0.8008  0.0146  0.0293  0.0903  0.6177  0.3052
# 3     0.0513  ...  0.1245  0.7544  0.0220  0.0024  0.0171  0.4883  0.2710
# 4     0.0488  ...  0.1465  0.5444  0.0146  0.0635  0.1074  0.7007  0.2930
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 6205  0.0732  ...  0.7837  0.7764  0.2197  0.1538  0.0903  0.6226  1.0596
# 6206  0.0635  ...  1.1035  0.8374  0.2637  0.0562  0.0659  0.4175  0.5835
# 6207  0.0586  ...  0.5273  0.4785  0.1025  0.0098  0.0439  0.3735  0.4492
# 6208  0.0684  ...  0.4639  0.1538  0.0659  0.0122  0.0146  0.6006  0.5444
# 6209  0.4712  ...  0.6519  0.3613  0.1489  0.0439  0.0781  0.6421  0.9229
#
#         1998    1999  target
# 0     0.4810  0.0757       1
# 1     0.1831  0.0757       1
# 2     0.3198  0.1025       1
# 3     0.4492  0.0757       1
# 4     0.1123  0.0708       1
# ...      ...     ...     ...
# 6205  0.1489  0.0977      23
# 6206  0.2637  0.0537      23
# 6207  0.1563  0.0732      23
# 6208  0.1514  0.0684      23
# 6209  0.1685  0.0781      23
#
# [6210 rows x 2001 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA

# training_acc_subjects = []
# test_acc_leave_one_ex3 = []

test_acc_leave_one_ex3 = {}
# Initialize lists for each model .. Each list should contain 27 values(number of subjects)

for label, model in models.items():
    test_acc_leave_one_ex3[label] = []
    
    
# Iterate over 27 subjects of Database 1 and trying to classify exercise 2
for sub in list(range(1,28)):
    
    start_idx_rows = (sub - 1) * 120
    end_idx_rows = start_idx_rows + 120
    training_data = df.drop(np.arange(start_idx_rows,end_idx_rows), axis=0)
    test_data = df[start_idx_rows:end_idx_rows]
    
    # Prepare X & y for the all-but-one subject and fit the model
    X_train = training_data.drop("target", axis=1)
    y_train = training_data["target"]

    # prepare X_test and y_test
    X_test = test_data.drop("target", axis=1)
    y_test = test_data["target"]
    
    for label, model in models.items():
        model.fit(X_train, y_train)
        score = model.score(X_test, y_test) * 100
        test_acc_leave_one_ex3[label].append(round(score, 3))
        print(f"Test Accuracy leaving subject {sub} out in exercise 3 using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------") 


for label, model in models.items():
    print(f"Average Test Accuracy for Exercise 3 leaving each subject out once using {label} is {np.mean(test_acc_leave_one_ex3[label])}")
# Out:
# Test Accuracy leaving subject 1 out in exercise 3 using LogisticRegression is 9.166666666666666
# Test Accuracy leaving subject 1 out in exercise 3 using RandomForestClassifier is 8.333333333333332
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 2 out in exercise 3 using LogisticRegression is 28.333333333333332
# Test Accuracy leaving subject 2 out in exercise 3 using RandomForestClassifier is 27.500000000000004
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 3 out in exercise 3 using LogisticRegression is 7.5
# Test Accuracy leaving subject 3 out in exercise 3 using RandomForestClassifier is 4.166666666666666
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 4 out in exercise 3 using LogisticRegression is 15.0
# Test Accuracy leaving subject 4 out in exercise 3 using RandomForestClassifier is 18.333333333333332
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 5 out in exercise 3 using LogisticRegression is 10.833333333333334
# Test Accuracy leaving subject 5 out in exercise 3 using RandomForestClassifier is 6.666666666666667
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 6 out in exercise 3 using LogisticRegression is 29.166666666666668
# Test Accuracy leaving subject 6 out in exercise 3 using RandomForestClassifier is 30.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 7 out in exercise 3 using LogisticRegression is 10.833333333333334
# Test Accuracy leaving subject 7 out in exercise 3 using RandomForestClassifier is 1.6666666666666667
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 8 out in exercise 3 using LogisticRegression is 15.833333333333332
# Test Accuracy leaving subject 8 out in exercise 3 using RandomForestClassifier is 20.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 9 out in exercise 3 using LogisticRegression is 21.666666666666668
# Test Accuracy leaving subject 9 out in exercise 3 using RandomForestClassifier is 8.333333333333332
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 10 out in exercise 3 using LogisticRegression is 38.333333333333336
# Test Accuracy leaving subject 10 out in exercise 3 using RandomForestClassifier is 26.666666666666668
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 11 out in exercise 3 using LogisticRegression is 28.333333333333332
# Test Accuracy leaving subject 11 out in exercise 3 using RandomForestClassifier is 16.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 12 out in exercise 3 using LogisticRegression is 36.666666666666664
# Test Accuracy leaving subject 12 out in exercise 3 using RandomForestClassifier is 29.166666666666668
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 13 out in exercise 3 using LogisticRegression is 14.166666666666666
# Test Accuracy leaving subject 13 out in exercise 3 using RandomForestClassifier is 8.333333333333332
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 14 out in exercise 3 using LogisticRegression is 20.833333333333336
# Test Accuracy leaving subject 14 out in exercise 3 using RandomForestClassifier is 30.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 15 out in exercise 3 using LogisticRegression is 33.33333333333333
# Test Accuracy leaving subject 15 out in exercise 3 using RandomForestClassifier is 40.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 16 out in exercise 3 using LogisticRegression is 23.333333333333332
# Test Accuracy leaving subject 16 out in exercise 3 using RandomForestClassifier is 25.833333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 17 out in exercise 3 using LogisticRegression is 18.333333333333332
# Test Accuracy leaving subject 17 out in exercise 3 using RandomForestClassifier is 19.166666666666668
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 18 out in exercise 3 using LogisticRegression is 18.333333333333332
# Test Accuracy leaving subject 18 out in exercise 3 using RandomForestClassifier is 12.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 19 out in exercise 3 using LogisticRegression is 10.0
# Test Accuracy leaving subject 19 out in exercise 3 using RandomForestClassifier is 25.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 20 out in exercise 3 using LogisticRegression is 19.166666666666668
# Test Accuracy leaving subject 20 out in exercise 3 using RandomForestClassifier is 17.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 21 out in exercise 3 using LogisticRegression is 45.0
# Test Accuracy leaving subject 21 out in exercise 3 using RandomForestClassifier is 43.333333333333336
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 22 out in exercise 3 using LogisticRegression is 28.333333333333332
# Test Accuracy leaving subject 22 out in exercise 3 using RandomForestClassifier is 29.166666666666668
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 23 out in exercise 3 using LogisticRegression is 30.0
# Test Accuracy leaving subject 23 out in exercise 3 using RandomForestClassifier is 36.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 24 out in exercise 3 using LogisticRegression is 10.0
# Test Accuracy leaving subject 24 out in exercise 3 using RandomForestClassifier is 10.833333333333334
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 25 out in exercise 3 using LogisticRegression is 25.0
# Test Accuracy leaving subject 25 out in exercise 3 using RandomForestClassifier is 16.666666666666664
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 26 out in exercise 3 using LogisticRegression is 35.833333333333336
# Test Accuracy leaving subject 26 out in exercise 3 using RandomForestClassifier is 27.500000000000004
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 27 out in exercise 3 using LogisticRegression is 32.5
# Test Accuracy leaving subject 27 out in exercise 3 using RandomForestClassifier is 35.833333333333336
# -----------------------------------------------------------------------------------
# Average Test Accuracy for Exercise 3 leaving each subject out once using LogisticRegression is 22.808555555555554
# Average Test Accuracy for Exercise 3 leaving each subject out once using RandomForestClassifier is 21.358037037037032

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,6))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_acc_leave_one_ex3[label])

ax.set_title("Test Scores leaving each subject out once for Exercise 3 using raw signal and different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0,100)
ax.legend(['Logistic Regression', 'Random Forest']);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

mean_accuracies_leave_one_ex3 = {}

for label, model in models.items():
    mean_accuracies_leave_one_ex3[label] = np.mean(test_acc_leave_one_ex3[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_leave_one_ex3.keys(), mean_accuracies_leave_one_ex3.values())
ax.set_title("Mean Accuracies of Different Models classifying Exercise 3 using leave-one-out approach")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_leave_one_ex3.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %%
ex1_mean = np.mean(test_acc_leave_one_ex1)
ex2_mean = np.mean(test_acc_leave_one_ex2)
ex3_mean = np.mean(test_acc_leave_one_ex3)

# %%
# Plot Bar graph to compare accuracy across exercises
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,8))
plt.rcParams.update({'font.size': 22})

exercises = ["Exercise 1", "Exercise 2", "Exercise 3"]
mean_accs = [ex1_mean, ex2_mean, ex3_mean]
ax.bar(exercises, mean_accs)
ax.set_title("Comparing Mean Test Accuracies across subjects for each Exercise")
ax.set_xlabel("Exercises")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accs):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# # 3. Classification of 52 movements per subject

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

models = {"LogisticRegression": LogisticRegression(max_iter=10000, n_jobs=-1),
         "RandomForestClassifier": RandomForestClassifier(n_estimators=100, n_jobs=-1)}

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

np.random.seed(42)

test_accuracy_all = {}

for label, model in models.items():
    test_accuracy_all[label] = []
    
ex1_movements = list(range(1,13))
ex2_movements = list(range(1,18))
ex3_movements = list(range(1,24))

# Iterate over 27 subjects of DB1 and trying to classify all exercises combined
for sub in list(range(1,28)):
    
    # Load the data for exercise 1
    data = load_data_DB1(subject=sub, exercise=1)
    
    # Iterate over all movements and add exercise 1 movement repetitions into a df
    ex1_df = pd.DataFrame()
    for m in ex1_movements:
        ex1_df = ex1_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    
    # Load the data for exercise 2
    data = load_data_DB1(subject=sub, exercise=2)

    # Iterate over all movements and add exercise 2 movement repetitions into a df
    ex2_df = pd.DataFrame()
    for m in ex2_movements:
        ex2_df = ex2_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    # Add 12 to target column of exercise 2 dataframe. The 12 number represents the number of movements in exercise 1
    ex2_df["target"] = ex2_df["target"] + 12
    
    # Load the data for exercise 3
    data = load_data_DB1(subject=sub, exercise=3)
    
    # Iterate over all movements and add exercise 3 movement repetitions into a df
    ex3_df = pd.DataFrame()
    for m in ex3_movements:
        ex3_df = ex3_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    # Add 29 to target column of exercise 3 dataframe. 
    # The 29 number represents the number of movements in exercise 1 plus the number of movements in exercise 2.
    ex3_df["target"] = ex3_df["target"] + 29
    
    data_df = pd.DataFrame() # A dataframe to hold data of all movements combined
    
    # Append 3 exercises to one dataframe
    data_df = data_df.append(ex1_df, ignore_index=True)
    data_df = data_df.append(ex2_df, ignore_index=True)
    data_df = data_df.append(ex3_df, ignore_index=True)
    
    
    # Getting X & y
    X = data_df.drop("target", axis=1)
    y = data_df["target"]

    # Splitting the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    
    # Fit models in the dictionary
    for label, model in models.items():
        model.fit(X_train, y_train)
        score = model.score(X_test, y_test) * 100
        test_accuracy_all[label].append(round(score, 3))
        print(f"Test Accuracy for subject {sub} classifying all 52 movements using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------")
        

for label, model in models.items():
    print(f"Average Test Accuracy for all subjects for all 52 movements using {label} {np.mean(test_accuracy_all[label])}")
# Out:
# Test Accuracy for subject 1 classifying all 52 movements using LogisticRegression is 76.92307692307693
# Test Accuracy for subject 1 classifying all 52 movements using RandomForestClassifier is 80.76923076923077
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 2 classifying all 52 movements using LogisticRegression is 85.57692307692307
# Test Accuracy for subject 2 classifying all 52 movements using RandomForestClassifier is 77.88461538461539
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 3 classifying all 52 movements using LogisticRegression is 72.11538461538461
# Test Accuracy for subject 3 classifying all 52 movements using RandomForestClassifier is 73.07692307692307
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 4 classifying all 52 movements using LogisticRegression is 76.92307692307693
# Test Accuracy for subject 4 classifying all 52 movements using RandomForestClassifier is 79.8076923076923
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 5 classifying all 52 movements using LogisticRegression is 70.1923076923077
# Test Accuracy for subject 5 classifying all 52 movements using RandomForestClassifier is 73.07692307692307
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 6 classifying all 52 movements using LogisticRegression is 79.8076923076923
# Test Accuracy for subject 6 classifying all 52 movements using RandomForestClassifier is 80.76923076923077
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 7 classifying all 52 movements using LogisticRegression is 81.73076923076923
# Test Accuracy for subject 7 classifying all 52 movements using RandomForestClassifier is 84.61538461538461
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 8 classifying all 52 movements using LogisticRegression is 91.34615384615384
# Test Accuracy for subject 8 classifying all 52 movements using RandomForestClassifier is 88.46153846153845
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 9 classifying all 52 movements using LogisticRegression is 79.8076923076923
# Test Accuracy for subject 9 classifying all 52 movements using RandomForestClassifier is 89.42307692307693
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 10 classifying all 52 movements using LogisticRegression is 78.84615384615384
# Test Accuracy for subject 10 classifying all 52 movements using RandomForestClassifier is 77.88461538461539
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 11 classifying all 52 movements using LogisticRegression is 80.76923076923077
# Test Accuracy for subject 11 classifying all 52 movements using RandomForestClassifier is 84.61538461538461
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 12 classifying all 52 movements using LogisticRegression is 85.57692307692307
# Test Accuracy for subject 12 classifying all 52 movements using RandomForestClassifier is 84.61538461538461
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 13 classifying all 52 movements using LogisticRegression is 66.34615384615384
# Test Accuracy for subject 13 classifying all 52 movements using RandomForestClassifier is 81.73076923076923
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 14 classifying all 52 movements using LogisticRegression is 76.92307692307693
# Test Accuracy for subject 14 classifying all 52 movements using RandomForestClassifier is 82.6923076923077
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 15 classifying all 52 movements using LogisticRegression is 79.8076923076923
# Test Accuracy for subject 15 classifying all 52 movements using RandomForestClassifier is 74.03846153846155
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 16 classifying all 52 movements using LogisticRegression is 72.11538461538461
# Test Accuracy for subject 16 classifying all 52 movements using RandomForestClassifier is 69.23076923076923
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 17 classifying all 52 movements using LogisticRegression is 86.53846153846155
# Test Accuracy for subject 17 classifying all 52 movements using RandomForestClassifier is 87.5
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 18 classifying all 52 movements using LogisticRegression is 76.92307692307693
# Test Accuracy for subject 18 classifying all 52 movements using RandomForestClassifier is 83.65384615384616
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 19 classifying all 52 movements using LogisticRegression is 74.03846153846155
# Test Accuracy for subject 19 classifying all 52 movements using RandomForestClassifier is 76.92307692307693
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 20 classifying all 52 movements using LogisticRegression is 87.5
# Test Accuracy for subject 20 classifying all 52 movements using RandomForestClassifier is 83.65384615384616
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 21 classifying all 52 movements using LogisticRegression is 96.15384615384616
# Test Accuracy for subject 21 classifying all 52 movements using RandomForestClassifier is 92.3076923076923
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 22 classifying all 52 movements using LogisticRegression is 89.42307692307693
# Test Accuracy for subject 22 classifying all 52 movements using RandomForestClassifier is 91.34615384615384
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 23 classifying all 52 movements using LogisticRegression is 72.11538461538461
# Test Accuracy for subject 23 classifying all 52 movements using RandomForestClassifier is 77.88461538461539
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 24 classifying all 52 movements using LogisticRegression is 82.6923076923077
# Test Accuracy for subject 24 classifying all 52 movements using RandomForestClassifier is 78.84615384615384
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 25 classifying all 52 movements using LogisticRegression is 91.34615384615384
# Test Accuracy for subject 25 classifying all 52 movements using RandomForestClassifier is 89.42307692307693
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 26 classifying all 52 movements using LogisticRegression is 90.38461538461539
# Test Accuracy for subject 26 classifying all 52 movements using RandomForestClassifier is 91.34615384615384
# -----------------------------------------------------------------------------------
# Test Accuracy for subject 27 classifying all 52 movements using LogisticRegression is 75.0
# Test Accuracy for subject 27 classifying all 52 movements using RandomForestClassifier is 79.8076923076923
# -----------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-b81c3ea958aa> in <module>
#      76
#      77 # print(f"Average Training Accuracy for all subjects in all exercises combined {np.mean(training_acc_subjects)}")
# ---> 78 print(f"Average Test Accuracy for all subjects for all 52 movements combined {np.mean(test_accuracy_all)}")
#      79
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3370             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3371
# -> 3372     return _methods._mean(a, axis=axis, dtype=dtype,
#    3373                           out=out, **kwargs)
#    3374
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     170             ret = ret.dtype.type(ret / rcount)
#     171     else:
# --> 172         ret = ret / rcount
#     173
#     174     return ret
#
# TypeError: unsupported operand type(s) for /: 'dict' and 'int'

# %%
for label, model in models.items():
    print(f"Average Test Accuracy for all subjects for all 52 movements using {label} {np.mean(test_accuracy_all[label])}")
# Out:
# Average Test Accuracy for all subjects for all 52 movements using LogisticRegression 80.62670370370371
# Average Test Accuracy for all subjects for all 52 movements using RandomForestClassifier 82.0512962962963

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,8))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_accuracy_all[label])

ax.set_title("Test Scores for 27 subjects for all 52 movements using raw signal using different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.legend(['Logistic Regression','Random Forest']);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 16})

mean_accuracies_all = {}

for label, model in models.items():
    mean_accuracies_all[label] = np.mean(test_accuracy_all[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_all.keys(), mean_accuracies_all.values())
ax.set_title("Mean Accuracies of Different Models classifying all 52 movements for all subjects")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_all.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')

# %% [markdown]
# ## Hyperparameter tuning

# %%
np.arange(10,100,10)
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
# Creating hyperparameter grid for random forest
rf_grid = {"n_estimators":np.arange(10,500,20),
          "max_depth":[None, 3, 5, 10],
          "min_samples_split":np.arange(2,20,2),
          "min_samples_leaf":np.arange(1,20,2),
          "max_features":["auto", "sqrt"]}

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, RandomizedSearchCV

np.random.seed(42)

test_accuracy_rf_hp = []

ex1_movements = list(range(1,13))
ex2_movements = list(range(1,18))
ex3_movements = list(range(1,24))

# Iterate over 27 subjects of DB1 and trying to classify all exercises combined
for sub in list(range(1,28)):
    
    # Load the data for exercise 1
    data = load_data_DB1(subject=sub, exercise=1)
    
    # Iterate over all movements and add exercise 1 movement repetitions into a df
    ex1_df = pd.DataFrame()
    for m in ex1_movements:
        ex1_df = ex1_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    
    # Load the data for exercise 2
    data = load_data_DB1(subject=sub, exercise=2)

    # Iterate over all movements and add exercise 2 movement repetitions into a df
    ex2_df = pd.DataFrame()
    for m in ex2_movements:
        ex2_df = ex2_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    # Add 12 to target column of exercise 2 dataframe. The 12 number represents the number of movements in exercise 1
    ex2_df["target"] = ex2_df["target"] + 12
    
    # Load the data for exercise 3
    data = load_data_DB1(subject=sub, exercise=3)
    
    # Iterate over all movements and add exercise 3 movement repetitions into a df
    ex3_df = pd.DataFrame()
    for m in ex3_movements:
        ex3_df = ex3_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    # Add 29 to target column of exercise 3 dataframe. 
    # The 29 number represents the number of movements in exercise 1 plus the number of movements in exercise 2.
    ex3_df["target"] = ex3_df["target"] + 29
    
    data_df = pd.DataFrame() # A dataframe to hold data of all movements combined
    
    # Append 3 exercises to one dataframe
    data_df = data_df.append(ex1_df, ignore_index=True)
    data_df = data_df.append(ex2_df, ignore_index=True)
    data_df = data_df.append(ex3_df, ignore_index=True)
    
    
    # Getting X & y
    X = data_df.drop("target", axis=1)
    y = data_df["target"]

    # Splitting the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    
    # Fit models in the dictionary
    randomizedSearch_reg = RandomizedSearchCV(estimator=RandomForestClassifier(n_jobs=-1),
                                             param_distributions=rf_grid,
                                             cv=5,
                                             n_iter=20,
                                             verbose=True)

    randomizedSearch_reg.fit(X_train, y_train)
    
    score = randomizedSearch_reg.score(X_test, y_test)
    test_accuracy_rf_hp.append(score)
    print(f'Best Params: {randomizedSearch_reg.best_params_}')
    print(f'Test Accuracy classifying 52 movements after Hyperparameter tuning: {score}')
    print("-----------------------------------------------------------------------------------")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 170, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7403846153846154
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 450, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 10}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7307692307692307
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 390, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.6730769230769231
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 330, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8269230769230769
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 450, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.6923076923076923
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 150, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 10}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7884615384615384
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 470, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7980769230769231
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 210, 'min_samples_split': 8, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7884615384615384
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 190, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 10}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8557692307692307
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 350, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7403846153846154
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 450, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8269230769230769
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 250, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7884615384615384
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 170, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7980769230769231
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 430, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7788461538461539
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 370, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 10}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7019230769230769
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 310, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.6730769230769231
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 410, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8365384615384616
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 350, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8653846153846154
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 310, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.75
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 290, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8076923076923077
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 70, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.9038461538461539
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 450, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.9230769230769231
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 390, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7307692307692307
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 90, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7788461538461539
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 170, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8173076923076923
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 270, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.8653846153846154
# -----------------------------------------------------------------------------------
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Params: {'n_estimators': 190, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'max_depth': None}
# Test Accuracy classifying 52 movements after Hyperparameter tuning: 0.7211538461538461
# -----------------------------------------------------------------------------------

# %%
np.mean(test_accuracy_rf_hp)
# Out:
# 0.7852564102564105

# %% [markdown]
# # 4. Classification of 52 movements using leave-one-out approach

# %%
ex1_movements = list(range(1,13))
ex2_movements = list(range(1,18))
ex3_movements = list(range(1,24))

all_exercises_df = pd.DataFrame()
# Load the data for all subjects except 1 to do leave-one out classification
for s in list(range(1,28)):
    ex1_df = pd.DataFrame()
    data = load_data_DB1(subject=s, exercise=1)
    # Iterate over all movements and add them into a df
    for m in ex1_movements:
        ex1_df = ex1_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
        
    ex2_df = pd.DataFrame()
    data = load_data_DB1(subject=s, exercise=2)
    # Iterate over all movements and add them into a df
    for m in ex2_movements:
        ex2_df = ex2_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
    
    ex2_df["target"] = ex2_df["target"] + 12
    
    ex3_df = pd.DataFrame()
    data = load_data_DB1(subject=s, exercise=3)
    # Iterate over all movements and add them into a df
    for m in ex3_movements:
        ex3_df = ex3_df.append(get_movement_df(data=data, movement=m, target="restimulus"),ignore_index=True)
        
    ex3_df["target"] = ex3_df["target"] + 12 + 17
    all_exercises_df = all_exercises_df.append(ex1_df, ignore_index=True)
    all_exercises_df = all_exercises_df.append(ex2_df, ignore_index=True)
    all_exercises_df = all_exercises_df.append(ex3_df, ignore_index=True)
all_exercises_df
# Out:
#             0       1       2       3       4       5       6       7       8  \
# 0      0.0171  0.0073  0.0024  0.0024  0.0024  0.0024  0.0757  0.0317  0.0024
# 1      0.0488  0.0073  0.0024  0.0024  0.0024  0.0024  0.0171  0.0488  0.0024
# 2      0.0073  0.0073  0.0024  0.0024  0.0024  0.0024  0.0269  0.0391  0.0024
# 3      0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0659  0.0342  0.0024
# 4      0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0098  0.0244  0.0049
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 14035  0.6982  0.1538  0.4712  0.0195  0.0049  0.0024  0.0342  0.4712  1.1426
# 14036  0.2686  0.0537  0.1929  0.0049  0.0049  0.0024  0.0073  0.2075  0.1147
# 14037  0.3491  0.1392  0.3320  0.0049  0.0024  0.0024  0.0122  0.2515  0.0732
# 14038  0.0757  0.0049  0.1172  0.0049  0.0049  0.0024  0.0049  0.0977  0.0659
# 14039  1.4136  0.7642  0.6616  0.0781  0.0439  0.0024  0.1099  0.5322  0.4736
#
#             9  ...    1991    1992    1993    1994    1995    1996    1997  \
# 0      0.0146  ...  0.0024  0.0195  0.0024  0.0024  0.0024  0.0146  0.0488
# 1      0.0049  ...  0.0269  0.0024  0.0049  0.0024  0.0024  0.0806  0.0659
# 2      0.0049  ...  0.2197  0.0562  0.0024  0.0024  0.0024  0.1318  0.0439
# 3      0.0098  ...  0.3931  0.2759  0.0171  0.0024  0.0024  0.3101  0.0952
# 4      0.0024  ...  0.1685  0.0024  0.0122  0.0024  0.0024  0.1196  0.0537
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# 14035  0.0732  ...  0.7837  0.7764  0.2197  0.1538  0.0903  0.6226  1.0596
# 14036  0.0635  ...  1.1035  0.8374  0.2637  0.0562  0.0659  0.4175  0.5835
# 14037  0.0586  ...  0.5273  0.4785  0.1025  0.0098  0.0439  0.3735  0.4492
# 14038  0.0684  ...  0.4639  0.1538  0.0659  0.0122  0.0146  0.6006  0.5444
# 14039  0.4712  ...  0.6519  0.3613  0.1489  0.0439  0.0781  0.6421  0.9229
#
#          1998    1999  target
# 0      0.0073  0.0024       1
# 1      0.0024  0.0024       1
# 2      0.2441  0.0122       1
# 3      0.5103  0.1880       1
# 4      0.0513  0.0024       1
# ...       ...     ...     ...
# 14035  0.1489  0.0977      52
# 14036  0.2637  0.0537      52
# 14037  0.1563  0.0732      52
# 14038  0.1514  0.0684      52
# 14039  0.1685  0.0781      52
#
# [14040 rows x 2001 columns]

# %%
all_exercises_df['target'] = all_exercises_df['target'].astype(int)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

models = {"LogisticRegression": LogisticRegression(max_iter=10000, n_jobs=-1),
         "RandomForestClassifier": RandomForestClassifier(n_estimators=100, n_jobs=-1)}

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA

test_acc_leave_one_all = {}

# Initialize lists for each model .. Each list should contain 27 values(number of subjects)
for label, model in models.items():
    test_acc_leave_one_all[label] = []
    
    
# Iterate over 27 subjects of Database 1 and trying to classify all exercises combined
for sub in list(range(1,28)):
    
    start_idx_rows = (sub - 1) * (120 + 170 + 230)
    end_idx_rows = start_idx_rows + (120 + 170 + 230)
    training_data = all_exercises_df.drop(np.arange(start_idx_rows,end_idx_rows), axis=0)
    test_data = all_exercises_df[start_idx_rows:end_idx_rows]
    
    # Prepare X & y for the all-but-one subject and fit the model
    X_train = training_data.drop("target", axis=1)
    y_train = training_data["target"]

    # prepare X_test and y_test
    X_test = test_data.drop("target", axis=1)
    y_test = test_data["target"]
    
    for label, model in models.items():
        model.fit(X_train, y_train)
        score = model.score(X_test, y_test) * 100
        test_acc_leave_one_all[label].append(round(score, 3))
        print(f"Test Accuracy leaving subject {sub} out for all movements using {label} is {score}")
    
    print("-----------------------------------------------------------------------------------") 


for label, model in models.items():
    print(f"Average Test Accuracy for all movements leaving each subject out once using {label} is {np.mean(test_acc_leave_one_all[label])}")
# Out:
# Test Accuracy leaving subject 1 out for all movements using LogisticRegression is 15.576923076923077
# Test Accuracy leaving subject 1 out for all movements using RandomForestClassifier is 20.192307692307693
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 2 out for all movements using LogisticRegression is 3.4615384615384617
# Test Accuracy leaving subject 2 out for all movements using RandomForestClassifier is 7.115384615384615
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 3 out for all movements using LogisticRegression is 19.615384615384617
# Test Accuracy leaving subject 3 out for all movements using RandomForestClassifier is 27.692307692307693
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 4 out for all movements using LogisticRegression is 18.653846153846153
# Test Accuracy leaving subject 4 out for all movements using RandomForestClassifier is 18.846153846153847
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 5 out for all movements using LogisticRegression is 18.653846153846153
# Test Accuracy leaving subject 5 out for all movements using RandomForestClassifier is 20.576923076923077
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 6 out for all movements using LogisticRegression is 29.807692307692307
# Test Accuracy leaving subject 6 out for all movements using RandomForestClassifier is 27.115384615384613
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 7 out for all movements using LogisticRegression is 8.846153846153847
# Test Accuracy leaving subject 7 out for all movements using RandomForestClassifier is 11.73076923076923
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 8 out for all movements using LogisticRegression is 35.0
# Test Accuracy leaving subject 8 out for all movements using RandomForestClassifier is 43.84615384615385
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 9 out for all movements using LogisticRegression is 14.038461538461538
# Test Accuracy leaving subject 9 out for all movements using RandomForestClassifier is 15.384615384615385
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 10 out for all movements using LogisticRegression is 16.923076923076923
# Test Accuracy leaving subject 10 out for all movements using RandomForestClassifier is 20.384615384615383
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 11 out for all movements using LogisticRegression is 28.653846153846153
# Test Accuracy leaving subject 11 out for all movements using RandomForestClassifier is 27.307692307692307
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 12 out for all movements using LogisticRegression is 22.5
# Test Accuracy leaving subject 12 out for all movements using RandomForestClassifier is 34.03846153846154
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 13 out for all movements using LogisticRegression is 15.0
# Test Accuracy leaving subject 13 out for all movements using RandomForestClassifier is 14.807692307692308
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 14 out for all movements using LogisticRegression is 28.46153846153846
# Test Accuracy leaving subject 14 out for all movements using RandomForestClassifier is 30.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 15 out for all movements using LogisticRegression is 28.46153846153846
# Test Accuracy leaving subject 15 out for all movements using RandomForestClassifier is 31.346153846153847
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 16 out for all movements using LogisticRegression is 23.46153846153846
# Test Accuracy leaving subject 16 out for all movements using RandomForestClassifier is 26.923076923076923
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 17 out for all movements using LogisticRegression is 35.96153846153846
# Test Accuracy leaving subject 17 out for all movements using RandomForestClassifier is 42.88461538461538
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 18 out for all movements using LogisticRegression is 27.500000000000004
# Test Accuracy leaving subject 18 out for all movements using RandomForestClassifier is 32.30769230769231
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 19 out for all movements using LogisticRegression is 18.653846153846153
# Test Accuracy leaving subject 19 out for all movements using RandomForestClassifier is 28.076923076923077
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 20 out for all movements using LogisticRegression is 25.576923076923073
# Test Accuracy leaving subject 20 out for all movements using RandomForestClassifier is 25.0
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 21 out for all movements using LogisticRegression is 34.80769230769231
# Test Accuracy leaving subject 21 out for all movements using RandomForestClassifier is 42.5
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 22 out for all movements using LogisticRegression is 26.153846153846157
# Test Accuracy leaving subject 22 out for all movements using RandomForestClassifier is 24.615384615384617
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 23 out for all movements using LogisticRegression is 20.0
# Test Accuracy leaving subject 23 out for all movements using RandomForestClassifier is 28.46153846153846
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 24 out for all movements using LogisticRegression is 20.384615384615383
# Test Accuracy leaving subject 24 out for all movements using RandomForestClassifier is 19.230769230769234
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 25 out for all movements using LogisticRegression is 41.92307692307693
# Test Accuracy leaving subject 25 out for all movements using RandomForestClassifier is 43.65384615384615
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 26 out for all movements using LogisticRegression is 27.115384615384613
# Test Accuracy leaving subject 26 out for all movements using RandomForestClassifier is 35.76923076923077
# -----------------------------------------------------------------------------------
# Test Accuracy leaving subject 27 out for all movements using LogisticRegression is 12.692307692307692
# Test Accuracy leaving subject 27 out for all movements using RandomForestClassifier is 16.923076923076923
# -----------------------------------------------------------------------------------
# Average Test Accuracy for all movements leaving each subject out once using LogisticRegression is 22.884703703703703
# Average Test Accuracy for all movements leaving each subject out once using RandomForestClassifier is 26.54559259259259

# %%
# Plot Average Accuracies for exercise 1
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,6))
plt.rcParams.update({'font.size': 22})

for label, model in models.items():
    ax.plot(np.arange(1,28), test_acc_leave_one_all[label])

ax.set_title("Test Scores leaving each subject out once for all movements using raw signal and different models")
ax.set_xlabel("Subjects")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0,100)
ax.legend(['Logistic Regression', 'Random Forest']);

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})

mean_accuracies_leave_one_all = {}

for label, model in models.items():
    mean_accuracies_leave_one_all[label] = np.mean(test_acc_leave_one_all[label])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))

ax.bar(mean_accuracies_leave_one_all.keys(), mean_accuracies_leave_one_all.values())
ax.set_title("Mean Accuracies of Different Models classifying 52 movements using leave-one-out approach")
ax.set_xlabel("Classification Models")
ax.set_ylabel("Accuracy (%)")
ax.set_ylim(0, 110);

rects = ax.patches
for rect, label in zip(rects, mean_accuracies_leave_one_all.values()):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 3, round(label, 2 ), ha='center', va='bottom')
